# %%
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
import matplotlib.pyplot as plt
import rasterio
import concurrent.futures

from netCDF4 import Dataset
from shapely.geometry import Point
from tqdm import tqdm
from shapely.vectorized import contains

import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore", category=UserWarning)

# %%
basin_info      = pd.read_excel('../../Data/Basin_Selection/All_Selected_Basins.xlsx')
basin_list      = basin_info['stat_num']
source_list     = basin_info['source']

# %% [markdown]
# # AE

# %%
# 读取 nc 文件
ds = xr.open_dataset("F:/GLEAM/v42a/E/E_1980_GLEAM_v4.2a_MO.nc")  # 替换为你的 nc 文件路径
lon = ds["lon"].to_numpy()
lat = ds["lat"].to_numpy()
AE_GLEAM = ds["E"].to_numpy()

for year in range(1981, 2023):
    ds = xr.open_dataset(f"F:/GLEAM/v42a/E/E_{str(year)}_GLEAM_v4.2a_MO.nc")  # 替换为你的 nc 文件路径
    temp_AE_GLEAM = ds["E"].to_numpy()
    AE_GLEAM = np.concatenate((AE_GLEAM, temp_AE_GLEAM), axis=0)
    print(f"Year {year} data loaded.")

time_series = pd.date_range(start='1980-01-01', end='2022-12-31', freq='MS')

# %%
for i in range(len(basin_list)):
    basin = str(basin_list[i])
    print(f"Processing No.{i+1}, {basin}...")
    source = source_list[i]
    if source == "ZHCN":
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + basin + ".shp"
    else:
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + source + "_" + basin + ".shp"
    # 读取shape文件
    gdf = gpd.read_file(shp_filepath)  # 替换为你的 shp 文件路径
    polygon = gdf.geometry
    minx, miny, maxx, maxy = polygon.total_bounds
    # 流域上下左右边界
    basin_left_bound = minx - 0.2
    basin_right_bound = maxx + 0.5
    basun_top_bound = maxy + 0.5
    basin_bottom_bound = miny - 0.2
    # 寻找落在流域边界内的格点
    lon_loc = np.where((lon >= basin_left_bound) & (lon <= basin_right_bound))[0]
    lat_loc = np.where((lat >= basin_bottom_bound) & (lat <= basun_top_bound))[0]
    temp_lon = lon[lon_loc]
    temp_lat = lat[lat_loc]
    temp_AE = AE_GLEAM[:, lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
    # 生成所有格点的经纬度坐标
    lon2d, lat2d = np.meshgrid(temp_lon, temp_lat)
    points = [Point(x, y) for x, y in zip(lon2d.ravel(), lat2d.ravel())]
    # 判断哪些点在流域内
    mask = np.array([polygon.contains(point) for point in points])
    mask = mask.reshape(lon2d.shape)  # 还原为 2D 形状
    new_mask = mask.copy().astype(np.float64)
    new_mask[new_mask == 0] = np.nan
    # 计算时间序列
    AE_series = np.nanmean(temp_AE * new_mask, axis=(1, 2))

    AE_filepath = f"../../Data/AE/AE_{basin}.txt"
    AE_df = pd.DataFrame({'Time': time_series, 'AE': AE_series})
    AE_df.set_index('Time', inplace=True)
    AE_df.to_csv(AE_filepath, sep="\t", float_format="%.3f", index=True, header=True)

# %% [markdown]
# # BFI

# %%
ds = xr.open_dataset("../../Raw_Data/BFI.nc")
lon = ds["longitude"].to_numpy()
lat = ds["latitude"].to_numpy()
BFI = ds["BFI"].to_numpy()
BFI = np.flip(np.rot90(BFI), axis=0)
plt.imshow(BFI)

# %%
BFI_list = np.full(len(basin_list), np.nan)
for i in range(len(basin_list)):
    basin = str(basin_list[i])
    print(f"Processing No.{i+1}, {basin}...")
    source = source_list[i]
    if source == "ZHCN":
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + basin + ".shp"
    else:
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + source + "_" + basin + ".shp"
    # 读取shape文件
    gdf = gpd.read_file(shp_filepath)  # 替换为你的 shp 文件路径
    polygon = gdf.geometry
    minx, miny, maxx, maxy = polygon.total_bounds
    # 流域上下左右边界
    basin_left_bound = minx - 0.2
    basin_right_bound = maxx + 0.5
    basun_top_bound = maxy + 0.5
    basin_bottom_bound = miny - 0.2
    # 寻找落在流域边界内的格点
    lon_loc = np.where((lon >= basin_left_bound) & (lon <= basin_right_bound))[0]
    lat_loc = np.where((lat >= basin_bottom_bound) & (lat <= basun_top_bound))[0]
    temp_lon = lon[lon_loc]
    temp_lat = lat[lat_loc]
    temp_BFI = BFI[lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
    # 生成所有格点的经纬度坐标
    lon2d, lat2d = np.meshgrid(temp_lon, temp_lat)
    points = [Point(x, y) for x, y in zip(lon2d.ravel(), lat2d.ravel())]
    # 判断哪些点在流域内
    mask = np.array([polygon.contains(point) for point in points])
    mask = mask.reshape(lon2d.shape)  # 还原为 2D 形状
    new_mask = mask.copy().astype(np.float64)
    new_mask[new_mask == 0] = np.nan

    BFI_basin = np.nanmean(temp_BFI * new_mask)
    BFI_list[i] = BFI_basin

BFI_filepath = f"../../Data/BFI/BFI.txt"
BFI_df = pd.DataFrame({'BFI': BFI_list}, index=basin_list)
BFI_df.to_csv(BFI_filepath, sep="\t", float_format="%.2f", index=True, header=True)

# %% [markdown]
# # Climate Zones

# %%
def get_mode(aa):
    """
    计算二维数组的众数，忽略NaN值
    :param aa: 二维数组
    :return: 众数
    """
    # 过滤NaN并展平为一维数组
    # 假设aa为二维数组
    flat_data = aa[~np.isnan(aa)]  # 过滤NaN并展平为一维数组
    if flat_data.size == 0:
        mode = None  # 处理全为NaN的情况
    else:
        values, counts = np.unique(flat_data, return_counts=True)
        mode = values[np.argmax(counts)]  # 取出现次数最多的值
    return mode

# %%
ds = xr.open_dataset("../../Raw_Data/Climate.nc")
lon  = ds["longitude"].to_numpy()
lat  = ds["latitude"].to_numpy()
Climate = ds["Climate"].to_numpy()
Climate = np.flip(np.rot90(Climate), axis=0)

# %%
def process_basin(args):
    i, basin, source = args
    try:
        if source == "ZHCN":
            shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + basin + ".shp"
        else:
            shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + source + "_" + basin + ".shp"
        
        # Read shapefile
        gdf = gpd.read_file(shp_filepath)
        polygon = gdf.geometry
        minx, miny, maxx, maxy = polygon.total_bounds
        
        # Basin boundaries
        basin_left_bound = minx - 0.2
        basin_right_bound = maxx + 0.5
        basun_top_bound = maxy + 0.5
        basin_bottom_bound = miny - 0.2
        
        # Find grid points within basin boundaries
        lon_loc = np.where((lon >= basin_left_bound) & (lon <= basin_right_bound))[0]
        lat_loc = np.where((lat >= basin_bottom_bound) & (lat <= basun_top_bound))[0]
        
        if len(lon_loc) == 0 or len(lat_loc) == 0:
            return i, np.nan
        
        temp_lon = lon[lon_loc]
        temp_lat = lat[lat_loc]
        temp_Climate = Climate[lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
        
        # Generate all grid point coordinates
        lon2d, lat2d = np.meshgrid(temp_lon, temp_lat)
        points = [Point(x, y) for x, y in zip(lon2d.ravel(), lat2d.ravel())]
        
        # Check which points are in the basin
        mask = np.array([polygon.contains(point) for point in points])
        mask = mask.reshape(lon2d.shape)
        new_mask = mask.copy().astype(np.float64)
        new_mask[new_mask == 0] = np.nan
        
        Climate_basin = get_mode(temp_Climate * new_mask)
        
        return i, Climate_basin
    except Exception as e:
        print(f"Error processing basin {basin} (index {i+1}): {e}")
        return i, np.nan

# Initialize the result array
Climate_list = np.full(len(basin_list), np.nan)

# Prepare arguments for the process_basin function
args_list = [(i, str(basin_list[i]), source_list[i]) for i in range(len(basin_list))]

# Process basins in parallel with a progress bar
max_workers = 12  # Adjust based on your CPU
with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
    results = list(tqdm(executor.map(process_basin, args_list), total=len(args_list), desc="Processing basins"))
    
    # Update Climate_list with results
    for i, result in results:
        Climate_list[i] = result

# Save results
Climate_filepath = f"../../Data/Climate.txt"
Climate_df = pd.DataFrame(Climate_list, columns=['Koppen'], index=basin_list)
Climate_df.to_csv(Climate_filepath, sep="\t", float_format="%.2f", index=True, header=True)
# Out:
# Processing basins: 100%|██████████| 2003/2003 [05:08<00:00,  6.50it/s]

# %% [markdown]
# # NDVI

# %%
# 读取 nc 文件
ds   = xr.open_dataset("F:/NDVI/GIMMS/NDVI_Global_1982_2022/NDVI_Global_1982_2022.nc")
lon  = ds["lon"].to_numpy()
lat  = ds["lat"].to_numpy()
NDVI = ds["NDVI"].to_numpy()
time_series = pd.date_range(start='1982-01-01', end='2022-12-31', freq='MS')

# %%
for i in range(len(basin_list)):
    basin = str(basin_list[i])
    print(f"Processing No.{i+1}, {basin}...")
    source = source_list[i]
    if source == "ZHCN":
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + basin + ".shp"
    else:
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + source + "_" + basin + ".shp"
    # 读取shape文件
    gdf = gpd.read_file(shp_filepath)  # 替换为你的 shp 文件路径
    polygon = gdf.geometry
    minx, miny, maxx, maxy = polygon.total_bounds
    # 流域上下左右边界
    basin_left_bound = minx - 0.2
    basin_right_bound = maxx + 0.5
    basun_top_bound = maxy + 0.5
    basin_bottom_bound = miny - 0.2
    # 寻找落在流域边界内的格点
    lon_loc = np.where((lon >= basin_left_bound) & (lon <= basin_right_bound))[0]
    lat_loc = np.where((lat >= basin_bottom_bound) & (lat <= basun_top_bound))[0]
    temp_lon = lon[lon_loc]
    temp_lat = lat[lat_loc]
    temp_DVI = NDVI[:, lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
    # 生成所有格点的经纬度坐标
    lon2d, lat2d = np.meshgrid(temp_lon, temp_lat)
    points = [Point(x, y) for x, y in zip(lon2d.ravel(), lat2d.ravel())]
    # 判断哪些点在流域内
    mask = np.array([polygon.contains(point) for point in points])
    mask = mask.reshape(lon2d.shape)  # 还原为 2D 形状
    new_mask = mask.copy().astype(np.float64)
    new_mask[new_mask == 0] = np.nan
    # 计算时间序列
    NDVI_series = np.nanmean(temp_DVI * new_mask, axis=(1, 2))

    NDVI_filepath = f"../../Data/NDVI/NDVI_{basin}.txt"
    NDVI_df = pd.DataFrame({'Time': time_series, 'NDVI': NDVI_series})
    NDVI_df.set_index('Time', inplace=True)
    NDVI_df.to_csv(NDVI_filepath, sep="\t", float_format="%.3f", index=True, header=True)

# %% [markdown]
# # Location

# %%
Location_list = np.full((len(basin_list), 5), np.nan)
for i in range(len(basin_list)):
    basin = str(basin_list[i])
    # print(f"Processing No.{i+1}, {basin}...")
    source = source_list[i]
    if source == "ZHCN":
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + basin + ".shp"
    else:
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + source + "_" + basin + ".shp"
    # 读取shape文件
    gdf = gpd.read_file(shp_filepath)  # 替换为你的 shp 文件路径
    polygon = gdf.geometry
    # Calculate the centroid (center) of the polygon
    centroid = polygon.centroid.values[0]
    center_lon, center_lat = centroid.x, centroid.y

    # Get bounds and calculate dimensions
    bounds = polygon.bounds.values[0]  # [minx, miny, maxx, maxy]
    xmin, ymin, xmax, ymax = bounds
    width = xmax - xmin   # in degrees longitude
    length = ymax - ymin  # in degrees latitude
    aspect_ratio = length / width if width > 0 else np.nan

    # Store values in Location_list
    Location_list[i, 0] = center_lat
    Location_list[i, 1] = center_lon
    Location_list[i, 2] = length
    Location_list[i, 3] = width
    Location_list[i, 4] = aspect_ratio
# Location_filepath = f"../../Data/Location.txt"
Location_df = pd.DataFrame(Location_list, columns=['clat', 'clon', 'length', 'width', 'aspect_ratio'], index=basin_list)
# Location_df.to_csv(Location_filepath, sep="\t", float_format="%.2f", index=True, header=True)

# %%
Location_df
# Out:
#                  clat        clon     length      width  aspect_ratio
# stat_num
# ZM_0000050  -9.555427   32.077578   1.176143   1.975659      0.595317
# ZM_0000053  -9.939214   30.858557   0.897713   1.159387      0.774300
# ZM_0000043 -11.195808   30.632132   4.431612   4.318066      1.026296
# CD_0000003  -7.868349   28.867774  12.060986  10.134900      1.190045
# CD_0000002  -6.967006   28.588987  13.538631  10.134900      1.335843
# ...               ...         ...        ...        ...           ...
# AU_0001056 -36.224709  147.689218   0.413707   0.396233      1.044101
# AU_0001063 -36.516600  147.042458   0.839917   0.608175      1.381045
# AU_0001087 -36.808596  146.811994   0.701920   0.666714      1.052805
# AU_0001127 -37.267236  146.143028   0.818595   1.004970      0.814547
# AU_0001128 -37.028153  145.661310   1.337374   1.999766      0.668765
#
# [2003 rows x 5 columns]

# %% [markdown]
# # Slope

# %%
# Path to the tif file
slope_path = '../../Raw_Data/Slope.tif'

# Open the raster file
with rasterio.open(slope_path) as src:
    # Read the data array
    slope_data = src.read(1)  # Read the first band
    # Get metadata
    slope_meta = src.meta
    # Create longitude and latitude arrays
    height = slope_meta['height']
    width = slope_meta['width']
    transform = slope_meta['transform']
    # Create coordinates
    rows = np.arange(height)
    cols = np.arange(width)
    # Transform pixel coordinates to geographic coordinates
    lon = np.zeros(width)
    lat = np.zeros(height)
    for col in range(width):
        lon[col] = transform[2] + (col * transform[0])
    for row in range(height):
        lat[row] = transform[5] + (row * transform[4])
    # Print some basic information
    print(f"Slope data shape: {slope_data.shape}")
    print(f"Longitude array shape: {lon.shape}")
    print(f"Latitude array shape: {lat.shape}")
    slope_data[slope_data > 10000] = np.nan
# Out:
# Slope data shape: (11907, 30836)
# Longitude array shape: (30836,)
# Latitude array shape: (11907,)

# %%
Slope_list = np.full((len(basin_list), 7), np.nan)
for i in range(len(basin_list)):
    basin = str(basin_list[i])
    print(f"Processing No.{i+1}, {basin}...")
    source = source_list[i]
    if source == "ZHCN":
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + basin + ".shp"
    else:
        shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + source + "_" + basin + ".shp"
    # 读取shape文件
    gdf = gpd.read_file(shp_filepath)  # 替换为你的 shp 文件路径
    polygon = gdf.geometry
    minx, miny, maxx, maxy = polygon.total_bounds
    # 流域上下左右边界
    basin_left_bound = minx - 0.2
    basin_right_bound = maxx + 0.5
    basun_top_bound = maxy + 0.5
    basin_bottom_bound = miny - 0.2
    # 寻找落在流域边界内的格点
    lon_loc = np.where((lon >= basin_left_bound) & (lon <= basin_right_bound))[0]
    lat_loc = np.where((lat >= basin_bottom_bound) & (lat <= basun_top_bound))[0]
    temp_lon = lon[lon_loc]
    temp_lat = lat[lat_loc]
    temp_Slope = slope_data[lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
    # Import vectorized contains function for fast point-in-polygon test

    # Create meshgrid
    lon2d, lat2d = np.meshgrid(temp_lon, temp_lat)

    # Get the polygon geometry
    basin_polygon = polygon.iloc[0]  # Extract the MultiPolygon from the GeoSeries

    # Use vectorized contains function for fast point-in-polygon test
    mask = contains(basin_polygon, lon2d.ravel(), lat2d.ravel())
    mask = mask.reshape(lon2d.shape)

    # Convert mask to float with NaN values for masked areas
    new_mask = mask.astype(np.float64)
    new_mask[new_mask == 0] = np.nan

    Slope_basin = temp_Slope * new_mask
    # Flatten the basin slope array and remove NaNs for calculation
    valid_slope = Slope_basin[~np.isnan(Slope_basin)]
    
    if len(valid_slope) > 0:
        # Calculate mean slope
        Slope_list[i, 0] = np.mean(valid_slope)
        # Calculate percentages in each slope range
        Slope_list[i, 1] = np.sum(valid_slope < 2) / len(valid_slope) * 100  # < 5
        Slope_list[i, 2] = np.sum((valid_slope >= 2) & (valid_slope < 5)) / len(valid_slope) * 100  # 5-10
        Slope_list[i, 3] = np.sum((valid_slope >= 5) & (valid_slope < 10)) / len(valid_slope) * 100  # 10-15
        Slope_list[i, 4] = np.sum((valid_slope >= 10) & (valid_slope < 15)) / len(valid_slope) * 100  # 15-20
        Slope_list[i, 5] = np.sum((valid_slope >= 15) & (valid_slope < 20)) / len(valid_slope) * 100  # 15-20
        Slope_list[i, 6] = np.sum(valid_slope >= 20) / len(valid_slope) * 100  # > 20
Slope_filepath = f"../../Data/Slope.txt"
Slope_df = pd.DataFrame(Slope_list, columns=['Ave', '<2', '2-5', '5-10', '10-15', '15-20', '>20'], index=basin_list)
Slope_df.to_csv(Slope_filepath, sep="\t", float_format="%.2f", index=True, header=True)

# %% [markdown]
# # Soil Texture

# %%
ds = xr.open_dataset("../../Raw_Data/CLAY.nc")
lon  = ds["longitude"].to_numpy()
lat  = ds["latitude"].to_numpy()
Clay = ds["CLAY"].to_numpy()
Clay = np.flip(np.rot90(Clay), axis=0)
ds = xr.open_dataset("../../Raw_Data/SAND.nc")
lon  = ds["longitude"].to_numpy()
lat  = ds["latitude"].to_numpy()
Sand = ds["SAND"].to_numpy()
Sand = np.flip(np.rot90(Sand), axis=0)
ds = xr.open_dataset("../../Raw_Data/SILT.nc")
lon  = ds["longitude"].to_numpy()
lat  = ds["latitude"].to_numpy()
Silt = ds["SILT"].to_numpy()
Silt = np.flip(np.rot90(Silt), axis=0)

# %%
def process_basin(args):
    i, basin, source = args
    try:
        if source == "ZHCN":
            shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + basin + ".shp"
        else:
            shp_filepath = "E:/2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + source + "_" + basin + ".shp"
        
        # Read shapefile
        gdf = gpd.read_file(shp_filepath)
        polygon = gdf.geometry
        minx, miny, maxx, maxy = polygon.total_bounds
        
        # Basin boundaries
        basin_left_bound = minx - 0.2
        basin_right_bound = maxx + 0.5
        basun_top_bound = maxy + 0.5
        basin_bottom_bound = miny - 0.2
        
        # Find grid points within basin boundaries
        lon_loc = np.where((lon >= basin_left_bound) & (lon <= basin_right_bound))[0]
        lat_loc = np.where((lat >= basin_bottom_bound) & (lat <= basun_top_bound))[0]
        
        if len(lon_loc) == 0 or len(lat_loc) == 0:
            return i, np.array([np.nan, np.nan, np.nan])
        
        temp_lon = lon[lon_loc]
        temp_lat = lat[lat_loc]
        temp_clay = Clay[lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
        temp_sand = Sand[lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
        temp_silt = Silt[lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
        
        # Generate all grid point coordinates
        lon2d, lat2d = np.meshgrid(temp_lon, temp_lat)
        points = [Point(x, y) for x, y in zip(lon2d.ravel(), lat2d.ravel())]
        
        # Check which points are in the basin
        mask = np.array([polygon.contains(point) for point in points])
        mask = mask.reshape(lon2d.shape)
        new_mask = mask.copy().astype(np.float64)
        new_mask[new_mask == 0] = np.nan
        
        Clay_basin = np.nanmean(temp_clay * new_mask)
        Sand_basin = np.nanmean(temp_sand * new_mask)
        Silt_basin = np.nanmean(temp_silt * new_mask)
        
        return i, np.array([Clay_basin, Sand_basin, Silt_basin])
    except Exception as e:
        print(f"Error processing basin {basin} (index {i+1}): {e}")
        return i, np.array([np.nan, np.nan, np.nan])

# Initialize the result array
Soil_list = np.full((len(basin_list), 3), np.nan)

# Prepare arguments for the process_basin function
args_list = [(i, str(basin_list[i]), source_list[i]) for i in range(len(basin_list))]

# Process basins in parallel with a progress bar
max_workers = 12  # Adjust based on your CPU
with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
    results = list(tqdm(executor.map(process_basin, args_list), total=len(args_list), desc="Processing basins"))
    
    # Update Soil_list with results
    for i, result in results:
        Soil_list[i] = result

# Save results
Soil_filepath = f"../../Data/Soil.txt"
Soil_df = pd.DataFrame(Soil_list, columns=['Clay', 'Sand', 'Silt'], index=basin_list)
Soil_df.to_csv(Soil_filepath, sep="\t", float_format="%.2f", index=True, header=True)
# Out:
# Processing basins: 100%|██████████| 2003/2003 [05:24<00:00,  6.18it/s]

# %% [markdown]
# # TI

# %%
ds = xr.open_dataset("../../Raw_Data/TI.nc")
lon  = ds["longitude"].to_numpy()
lat  = ds["latitude"].to_numpy()
TI = ds["TI"].to_numpy()
TI = np.flip(np.rot90(TI), axis=0)

# %%
def process_basin(args):
    i, basin, source = args
    try:
        if source == "ZHCN":
            shp_filepath = "../../../2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + basin + ".shp"
        else:
            shp_filepath = "../../../2024_01_Global_WBM_Validation/Raw_Data/Boundary/" + source + "_" + basin + ".shp"
        
        # Read shapefile
        gdf = gpd.read_file(shp_filepath)
        polygon = gdf.geometry
        minx, miny, maxx, maxy = polygon.total_bounds
        
        # Basin boundaries
        basin_left_bound = minx - 0.2
        basin_right_bound = maxx + 0.5
        basun_top_bound = maxy + 0.5
        basin_bottom_bound = miny - 0.2
        
        # Find grid points within basin boundaries
        lon_loc = np.where((lon >= basin_left_bound) & (lon <= basin_right_bound))[0]
        lat_loc = np.where((lat >= basin_bottom_bound) & (lat <= basun_top_bound))[0]
        
        if len(lon_loc) == 0 or len(lat_loc) == 0:
            return i, np.array([np.nan, np.nan, np.nan])
        
        temp_lon = lon[lon_loc]
        temp_lat = lat[lat_loc]
        temp_TI = TI[lat_loc[0]:lat_loc[-1]+1, lon_loc[0]:lon_loc[-1]+1]
        
        # Generate all grid point coordinates
        lon2d, lat2d = np.meshgrid(temp_lon, temp_lat)
        points = [Point(x, y) for x, y in zip(lon2d.ravel(), lat2d.ravel())]
        
        # Check which points are in the basin
        mask = np.array([polygon.contains(point) for point in points])
        mask = mask.reshape(lon2d.shape)
        new_mask = mask.copy().astype(np.float64)
        new_mask[new_mask == 0] = np.nan
        
        TI_basin = np.nanmean(temp_TI * new_mask)
        
        return i, TI_basin
    except Exception as e:
        print(f"Error processing basin {basin} (index {i+1}): {e}")
        return i, np.array([np.nan, np.nan, np.nan])

# Initialize the result array
TI_list = np.full(len(basin_list), np.nan)

# Prepare arguments for the process_basin function
args_list = [(i, str(basin_list[i]), source_list[i]) for i in range(len(basin_list))]

# Process basins in parallel with a progress bar
max_workers = 12  # Adjust based on your CPU
with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
    results = list(tqdm(executor.map(process_basin, args_list), total=len(args_list), desc="Processing basins"))
    
    # Update TI_list with results
    for i, result in results:
        TI_list[i] = result

# Save results
TI_filepath = f"../../Data/TI.txt"
TI_df = pd.DataFrame(TI_list, columns=['TI'], index=basin_list)
TI_df.to_csv(TI_filepath, sep="\t", float_format="%.2f", index=True, header=True)
# Out:
# Processing basins: 100%|██████████| 2003/2003 [05:20<00:00,  6.25it/s]

# %% [markdown]
# # Basin Properties

# %%
Basin_Properties = pd.DataFrame({}, index=basin_list)
# 气候条件
Climate = pd.read_csv("../../Data/Properties/Climate.txt", sep = '\t', header=0, index_col=0)
Basin_Properties['Climate'] = Climate['Koppen'].to_numpy()

# 土壤属性
Soil    = pd.read_csv("../../Data/Properties/Soil.txt", sep = '\t', header=0, index_col=0)
Basin_Properties['Clay'] = Soil['Clay'].to_numpy()
Basin_Properties['Silt'] = Soil['Silt'].to_numpy()
Basin_Properties['Sand'] = Soil['Sand'].to_numpy()

# 流域位置属性
Location = pd.read_csv("../../Data/Properties/Location.txt", sep = '\t', header=0, index_col=0)
Basin_Properties['Longitude'] = Location['clon'].to_numpy()
Basin_Properties['Latitude']  = Location['clat'].to_numpy()
Basin_Properties['Length']    = Location['length'].to_numpy()
Basin_Properties['Width']     = Location['width'].to_numpy()
Basin_Properties['Asp_Rat']   = Location['aspect_ratio'].to_numpy()

# 坡度
Slope   = pd.read_csv("../../Data/Properties/Slope.txt", sep = '\t', header=0, index_col=0)
Basin_Properties['Slope'] = Slope['Ave'].to_numpy()

# 面积
Basin_Properties['Area'] = np.round(basin_info['area'].to_numpy(), 2)

# 基流指数
BFI  = pd.read_csv("../../Data/Properties/BFI.txt", sep = '\t', header=0, index_col=0)
Basin_Properties['BFI'] = BFI['BFI'].to_numpy()

# 地形指数
TI = pd.read_csv("../../Data/TI.txt", sep = '\t', header=0, index_col=0)
Basin_Properties['TI'] = TI['TI'].to_numpy()

# 流域气候条件
PRE_list  = np.full(len(basin_list), np.nan)
TMP_list  = np.full(len(basin_list), np.nan)
PET_list  = np.full(len(basin_list), np.nan)
TMAX_list = np.full(len(basin_list), np.nan)
TMIN_list = np.full(len(basin_list), np.nan)
AE_list   = np.full(len(basin_list), np.nan)
NDVI_list = np.full(len(basin_list), np.nan)
for b in range(len(basin_list)):
    basin = str(basin_list[b])
    print(f"Processing No.{b+1}, {basin}...")
    # 基于CRU的气候数据
    HC_filepath = f"../../../2025_03_Hydrological_Models/Data/New_Hydro_Climatic/NHC_{basin}.txt"
    HC_data = pd.read_csv(HC_filepath, sep = '\t', header=0, index_col='Time', parse_dates=['Time'])
    PRE_list[b]  = HC_data['PRE_CRU'].mean()
    TMP_list[b]  = HC_data['TMP_CRU'].mean()
    PET_list[b]  = HC_data['PET_CRU'].mean()
    TMAX_list[b] = HC_data['TMAX_CRU'].mean()
    TMIN_list[b] = HC_data['TMIN_CRU'].mean()
    if np.isnan(HC_data['TMAX_CRU'].mean()):
        TMAX_list[b] = HC_data['TMP_CRU'].mean()
        TMIN_list[b] = HC_data['TMP_CRU'].mean()
    # 基于GLEAM的实际蒸散发数据
    AE_filepath = f"../../Data/AE/AE_{basin}.txt"
    AE_data = pd.read_csv(AE_filepath, sep = '\t', header=0, index_col='Time', parse_dates=['Time'])
    AE_list[b] = AE_data['AE'].mean()
    # 基于GIMMS的NDVI数据
    NDVI_filepath = f"../../Data/NDVI/NDVI_{basin}.txt"
    NDVI_data = pd.read_csv(NDVI_filepath, sep = '\t', header=0, index_col='Time', parse_dates=['Time'])
    NDVI_list[b] = NDVI_data['NDVI'].mean()/10000

Basin_Properties['PRE']  = PRE_list
Basin_Properties['TMP']  = TMP_list
Basin_Properties['PET']  = PET_list
Basin_Properties['TMAX'] = TMAX_list
Basin_Properties['TMIN'] = TMIN_list
Basin_Properties['AE']   = AE_list
Basin_Properties['NDVI'] = NDVI_list

Basin_Properties.to_csv("../../Data/Properties/Basin_Properties.txt", sep = '\t', index = True, header=True)
# Out:
# Processing No.1, ZM_0000050...
# Processing No.2, ZM_0000053...
# Processing No.3, ZM_0000043...
# Processing No.4, CD_0000003...
# Processing No.5, CD_0000002...
# Processing No.6, CD_0000006...
# Processing No.7, CD_0000005...
# Processing No.8, CF_0000010...
# Processing No.9, ET_0000002...
# Processing No.10, MZ_0000001...
# Processing No.11, TZ_0000051...
# Processing No.12, TZ_0000027...
# Processing No.13, TZ_0000024...
# Processing No.14, TZ_0000007...
# Processing No.15, TZ_0000032...
# Processing No.16, MW_0000014...
# Processing No.17, MW_0000019...
# Processing No.18, MW_0000020...
# Processing No.19, ZM_0000004...
# Processing No.20, ZM_0000042...
# Processing No.21, ZM_0000003...
# Processing No.22, ZM_0000029...
# Processing No.23, ZM_0000025...
# Processing No.24, ZM_0000016...
# Processing No.25, ZM_0000040...
# Processing No.26, NA_0000003...
# Processing No.27, NA_0000004...
# Processing No.28, ZW_0000049...
# Processing No.29, ZW_0000064...
# Processing No.30, TD_0000003...
# Processing No.31, NG_0000004...
# Processing No.32, CI_0000042...
# Processing No.33, ML_0000025...
# Processing No.34, ML_0000027...
# Processing No.35, ML_0000029...
# Processing No.36, ML_0000031...
# Processing No.37, ML_0000032...
# Processing No.38, NE_0000005...
# Processing No.39, NE_0000006...
# Processing No.40, BJ_0000020...
# Processing No.41, ZA_0000168...
# Processing No.42, ZA_0000070...
# Processing No.43, ZA_0000075...
# Processing No.44, ZA_0000265...
# Processing No.45, ZA_0000001...
# Processing No.46, CI_0000004...
# Processing No.47, CI_0000030...
# Processing No.48, MZ_0000014...
# Processing No.49, MZ_0000007...
# Processing No.50, 1749550...
# Processing No.51, 1749480...
# Processing No.52, 1348151...
# Processing No.53, 1448100...
# Processing No.54, 1880100...
# Processing No.55, 1789300...
# Processing No.56, 1389100...
# Processing No.57, 1389230...
# Processing No.58, 1389500...
# Processing No.59, 1389600...
# Processing No.60, 1389470...
# Processing No.61, 1286660...
# Processing No.62, 1293300...
# Processing No.63, 1591235...
# Processing No.64, 1255100...
# Processing No.65, 1491700...
# Processing No.66, 1491580...
# Processing No.67, 1445100...
# Processing No.68, 1445050...
# Processing No.69, 1643100...
# Processing No.70, 1340500...
# Processing No.71, 1339100...
# Processing No.72, 1338050...
# Processing No.73, 1338400...
# Processing No.74, 1338600...
# Processing No.75, 1338300...
# Processing No.76, 1338401...
# Processing No.77, 1337100...
# Processing No.78, 1537250...
# Processing No.79, 1335181...
# Processing No.80, 1835800...
# Processing No.81, 1335500...
# Processing No.82, 1537100...
# Processing No.83, 1837410...
# Processing No.84, 1321880...
# Processing No.85, 1322880...
# Processing No.86, 1323580...
# Processing No.87, 1619600...
# Processing No.88, 1616700...
# Processing No.89, 1617800...
# Processing No.90, 1815020...
# Processing No.91, 1812100...
# Processing No.92, 1812300...
# Processing No.93, 1531700...
# Processing No.94, 1733600...
# Processing No.95, 1634200...
# Processing No.96, 1634560...
# Processing No.97, 1434200...
# Processing No.98, 1634400...
# Processing No.99, 1634420...
# Processing No.100, 1634500...
# Processing No.101, 1634800...
# Processing No.102, 1634600...
# Processing No.103, 1634700...
# Processing No.104, 1134020...
# Processing No.105, 1134050...
# Processing No.106, 1134030...
# Processing No.107, 1134040...
# Processing No.108, 1134100...
# Processing No.109, 1134200...
# Processing No.110, 1134220...
# Processing No.111, 1134300...
# Processing No.112, 1134250...
# Processing No.113, 1134460...
# Processing No.114, 1134650...
# Processing No.115, 1134620...
# Processing No.116, 1234090...
# Processing No.117, 1734450...
# Processing No.118, 1734300...
# Processing No.119, 1731400...
# Processing No.120, 1734410...
# Processing No.121, 1734560...
# Processing No.122, 1931070...
# Processing No.123, 1931160...
# Processing No.124, 1324580...
# Processing No.125, 1160777...
# Processing No.126, 1160682...
# Processing No.127, 1160880...
# Processing No.128, 1160883...
# Processing No.129, 1160302...
# Processing No.130, 2595700...
# Processing No.131, 2595300...
# Processing No.132, 2421200...
# Processing No.133, 2421400...
# Processing No.134, 2335950...
# Processing No.135, 2517700...
# Processing No.136, 2517850...
# Processing No.137, 2517920...
# Processing No.138, 2517900...
# Processing No.139, 2517610...
# Processing No.140, 2217200...
# Processing No.141, 2416665...
# Processing No.142, 2816650...
# Processing No.143, 2416760...
# Processing No.144, 2416890...
# Processing No.145, 2416750...
# Processing No.146, 2416870...
# Processing No.147, 2617110...
# Processing No.148, 2240301...
# Processing No.149, 2240210...
# Processing No.150, 2217120...
# Processing No.151, 2217210...
# Processing No.152, 2817100...
# Processing No.153, 2997115...
# Processing No.154, 2106500...
# Processing No.155, 2998800...
# Processing No.156, 2901300...
# Processing No.157, 2998702...
# Processing No.158, 2998735...
# Processing No.159, 2998510...
# Processing No.160, 2998200...
# Processing No.161, 2998511...
# Processing No.162, 2998505...
# Processing No.163, 2998454...
# Processing No.164, 2998320...
# Processing No.165, 2903418...
# Processing No.166, 2903983...
# Processing No.167, 2903412...
# Processing No.168, 2903993...
# Processing No.169, 2903985...
# Processing No.170, 2903981...
# Processing No.171, 2902800...
# Processing No.172, 2909570...
# Processing No.173, 2909560...
# Processing No.174, 2909550...
# Processing No.175, 2999112...
# Processing No.176, 2999461...
# Processing No.177, 2999471...
# Processing No.178, 2999470...
# Processing No.179, 2911150...
# Processing No.180, 2911590...
# Processing No.181, 2910570...
# Processing No.182, 2910560...
# Processing No.183, 2910564...
# Processing No.184, 2910515...
# Processing No.185, 2910510...
# Processing No.186, 2910660...
# Processing No.187, 2910581...
# Processing No.188, 2999920...
# Processing No.189, 2999150...
# Processing No.190, 2903704...
# Processing No.191, 2903741...
# Processing No.192, 2903701...
# Processing No.193, 2903427...
# Processing No.194, 2903215...
# Processing No.195, 2903491...
# Processing No.196, 2903240...
# Processing No.197, 2903058...
# Processing No.198, 2903481...
# Processing No.199, 2903480...
# Processing No.200, 2903490...
# Processing No.201, 2903630...
# Processing No.202, 2903647...
# Processing No.203, 2906300...
# Processing No.204, 2903402...
# Processing No.205, 2903401...
# Processing No.206, 2903605...
# Processing No.207, 2907227...
# Processing No.208, 2907041...
# Processing No.209, 2907042...
# Processing No.210, 2907030...
# Processing No.211, 2907031...
# Processing No.212, 2907019...
# Processing No.213, 2907081...
# Processing No.214, 2908150...
# Processing No.215, 2908180...
# Processing No.216, 2903421...
# Processing No.217, 2903330...
# Processing No.218, 2903310...
# Processing No.219, 2909702...
# Processing No.220, 2909401...
# Processing No.221, 2911671...
# Processing No.222, 2911875...
# Processing No.223, 2911702...
# Processing No.224, 2912552...
# Processing No.225, 2912555...
# Processing No.226, 2911670...
# Processing No.227, 2911307...
# Processing No.228, 2911305...
# Processing No.229, 2911470...
# Processing No.230, 2911400...
# Processing No.231, 2910170...
# Processing No.232, 2910100...
# Processing No.233, 2910240...
# Processing No.234, 2910250...
# Processing No.235, 2910230...
# Processing No.236, 2997250...
# Processing No.237, 2997510...
# Processing No.238, 2912556...
# Processing No.239, 2911870...
# Processing No.240, 2311479...
# Processing No.241, 2910312...
# Processing No.242, 2910313...
# Processing No.243, 2910365...
# Processing No.244, 2910370...
# Processing No.245, 2998560...
# Processing No.246, 2909160...
# Processing No.247, 2910200...
# Processing No.248, 2910318...
# Processing No.249, 2909361...
# Processing No.250, 2998451...
# Processing No.251, 2311109...
# Processing No.252, 2319200...
# Processing No.253, 2853200...
# Processing No.254, 2854700...
# Processing No.255, 2854500...
# Processing No.256, 2854400...
# Processing No.257, 2854100...
# Processing No.258, 2854300...
# Processing No.259, 2856900...
# Processing No.260, 2856550...
# Processing No.261, 2853300...
# Processing No.262, 2853500...
# Processing No.263, 2854050...
# Processing No.264, 2846800...
# Processing No.265, 2548620...
# Processing No.266, 2548550...
# Processing No.267, 2548500...
# Processing No.268, 2151100...
# Processing No.269, 2260700...
# Processing No.270, 2261500...
# Processing No.271, 2263100...
# Processing No.272, 2569002...
# Processing No.273, 2569005...
# Processing No.274, 2969200...
# Processing No.275, 2569025...
# Processing No.276, 2964080...
# Processing No.277, 2966999...
# Processing No.278, 2969010...
# Processing No.279, 2969011...
# Processing No.280, 2969009...
# Processing No.281, 2469140...
# Processing No.282, 2469058...
# Processing No.283, 2969095...
# Processing No.284, 2969100...
# Processing No.285, 2969101...
# Processing No.286, 2469072...
# Processing No.287, AF_0000029...
# Processing No.288, IN_0000127...
# Processing No.289, IN_0000061...
# Processing No.290, IN_0000071...
# Processing No.291, IN_0000075...
# Processing No.292, IN_0000237...
# Processing No.293, IN_0000234...
# Processing No.294, IN_0000247...
# Processing No.295, IN_0000241...
# Processing No.296, IN_0000242...
# Processing No.297, IN_0000226...
# Processing No.298, IN_0000253...
# Processing No.299, IN_0000062...
# Processing No.300, IN_0000033...
# Processing No.301, IN_0000036...
# Processing No.302, IN_0000028...
# Processing No.303, IN_0000042...
# Processing No.304, IN_0000114...
# Processing No.305, IN_0000176...
# Processing No.306, IN_0000169...
# Processing No.307, IN_0000230...
# Processing No.308, IN_0000232...
# Processing No.309, TH_0000161...
# Processing No.310, LA_0000009...
# Processing No.311, LA_0000006...
# Processing No.312, LA_0000002...
# Processing No.313, CN_0000006...
# Processing No.314, TH_0000044...
# Processing No.315, TH_0000041...
# Processing No.316, TH_0000022...
# Processing No.317, RU_0000009...
# Processing No.318, RU_0000010...
# Processing No.319, RU_0000022...
# Processing No.320, RU_0000032...
# Processing No.321, RU_0000043...
# Processing No.322, RU_0000048...
# Processing No.323, RU_0000059...
# Processing No.324, RU_0000064...
# Processing No.325, RU_0000069...
# Processing No.326, RU_0000070...
# Processing No.327, RU_0000075...
# Processing No.328, RU_0000079...
# Processing No.329, RU_0000088...
# Processing No.330, RU_0000096...
# Processing No.331, RU_0000100...
# Processing No.332, RU_0000103...
# Processing No.333, RU_0000367...
# Processing No.334, RU_0000381...
# Processing No.335, RU_0000384...
# Processing No.336, RU_0000385...
# Processing No.337, RU_0000393...
# Processing No.338, RU_0000397...
# Processing No.339, RU_0000398...
# Processing No.340, RU_0000400...
# Processing No.341, RU_0000401...
# Processing No.342, RU_0000406...
# Processing No.343, RU_0000407...
# Processing No.344, RU_0000408...
# Processing No.345, RU_0000409...
# Processing No.346, RU_0000411...
# Processing No.347, RU_0000416...
# Processing No.348, RU_0000418...
# Processing No.349, RU_0000420...
# Processing No.350, RU_0000440...
# Processing No.351, 1878300...
# Processing No.352, 1577602...
# Processing No.353, 1870800...
# Processing No.354, 1663800...
# Processing No.355, 1663100...
# Processing No.356, 1664100...
# Processing No.357, 1308600...
# Processing No.358, 1309700...
# Processing No.359, 1309600...
# Processing No.360, 1813320...
# Processing No.361, 1426380...
# Processing No.362, 1427500...
# Processing No.363, ZG_001...
# Processing No.364, ZG_002...
# Processing No.365, ZG_004...
# Processing No.366, ZG_005...
# Processing No.367, ZG_006...
# Processing No.368, ZG_007...
# Processing No.369, ZG_009...
# Processing No.370, ZG_015...
# Processing No.371, ZG_017...
# Processing No.372, ZG_018...
# Processing No.373, ZG_019...
# Processing No.374, ZG_020...
# Processing No.375, ZG_021...
# Processing No.376, ZG_022...
# Processing No.377, ZG_023...
# Processing No.378, ZG_024...
# Processing No.379, ZG_026...
# Processing No.380, ZG_028...
# Processing No.381, ZG_030...
# Processing No.382, ZG_031...
# Processing No.383, ZG_032...
# Processing No.384, ZG_033...
# Processing No.385, ZG_034...
# Processing No.386, ZG_035...
# Processing No.387, ZG_036...
# Processing No.388, ZG_037...
# Processing No.389, ZG_038...
# Processing No.390, ZG_039...
# Processing No.391, ZG_040...
# Processing No.392, ZG_041...
# Processing No.393, ZG_042...
# Processing No.394, ZG_043...
# Processing No.395, ZG_044...
# Processing No.396, ZG_045...
# Processing No.397, ZG_047...
# Processing No.398, ZG_048...
# Processing No.399, ZG_049...
# Processing No.400, ZG_050...
# Processing No.401, ZG_052...
# Processing No.402, ZG_053...
# Processing No.403, ZG_054...
# Processing No.404, ZG_055...
# Processing No.405, ZG_056...
# Processing No.406, ZG_058...
# Processing No.407, ZG_059...
# Processing No.408, ZG_060...
# Processing No.409, ZG_061...
# Processing No.410, ZG_062...
# Processing No.411, ZG_066...
# Processing No.412, ZG_067...
# Processing No.413, ZG_068...
# Processing No.414, ZG_070...
# Processing No.415, ZG_072...
# Processing No.416, ZG_073...
# Processing No.417, ZG_074...
# Processing No.418, ZG_075...
# Processing No.419, ZG_076...
# Processing No.420, ZG_078...
# Processing No.421, ZG_079...
# Processing No.422, ZG_081...
# Processing No.423, ZG_082...
# Processing No.424, ZG_083...
# Processing No.425, ZG_084...
# Processing No.426, ZG_085...
# Processing No.427, ZG_086...
# Processing No.428, ZG_087...
# Processing No.429, ZG_088...
# Processing No.430, ZG_090...
# Processing No.431, ZG_091...
# Processing No.432, ZG_092...
# Processing No.433, ZG_093...
# Processing No.434, ZG_094...
# Processing No.435, ZG_095...
# Processing No.436, ZG_096...
# Processing No.437, ZG_097...
# Processing No.438, ZG_098...
# Processing No.439, ZG_099...
# Processing No.440, ZG_100...
# Processing No.441, ZG_101...
# Processing No.442, ZG_103...
# Processing No.443, ZG_105...
# Processing No.444, ZG_106...
# Processing No.445, ZG_108...
# Processing No.446, ZG_110...
# Processing No.447, ZG_111...
# Processing No.448, ZG_112...
# Processing No.449, ZG_113...
# Processing No.450, ZG_115...
# Processing No.451, ZG_117...
# Processing No.452, ZG_118...
# Processing No.453, ZG_119...
# Processing No.454, ZG_120...
# Processing No.455, ZG_121...
# Processing No.456, ZG_122...
# Processing No.457, ZG_123...
# Processing No.458, ZG_124...
# Processing No.459, ZG_125...
# Processing No.460, ZG_126...
# Processing No.461, ZG_127...
# Processing No.462, ZG_128...
# Processing No.463, ZG_129...
# Processing No.464, ZG_130...
# Processing No.465, ZG_131...
# Processing No.466, ZG_132...
# Processing No.467, ZG_133...
# Processing No.468, ZG_134...
# Processing No.469, ZG_135...
# Processing No.470, ZG_136...
# Processing No.471, ZG_137...
# Processing No.472, ZG_138...
# Processing No.473, ZG_139...
# Processing No.474, ZG_140...
# Processing No.475, ZG_141...
# Processing No.476, ZG_142...
# Processing No.477, ZG_143...
# Processing No.478, ZG_144...
# Processing No.479, ZG_145...
# Processing No.480, ZG_148...
# Processing No.481, ZG_150...
# Processing No.482, ZG_151...
# Processing No.483, ZG_154...
# Processing No.484, ZG_157...
# Processing No.485, ZG_158...
# Processing No.486, ZG_159...
# Processing No.487, ZG_160...
# Processing No.488, ZG_161...
# Processing No.489, ZG_162...
# Processing No.490, ZG_163...
# Processing No.491, ZG_164...
# Processing No.492, ZG_165...
# Processing No.493, ZG_166...
# Processing No.494, ZG_167...
# Processing No.495, ZG_168...
# Processing No.496, ZG_169...
# Processing No.497, ZG_170...
# Processing No.498, ZG_171...
# Processing No.499, ZG_172...
# Processing No.500, ZG_173...
# Processing No.501, ZG_174...
# Processing No.502, ZG_175...
# Processing No.503, ZG_176...
# Processing No.504, ZG_177...
# Processing No.505, ZG_178...
# Processing No.506, ZG_179...
# Processing No.507, ZG_180...
# Processing No.508, ZG_181...
# Processing No.509, ZG_182...
# Processing No.510, ZG_183...
# Processing No.511, ZG_184...
# Processing No.512, ZG_185...
# Processing No.513, ZG_187...
# Processing No.514, ZG_188...
# Processing No.515, ZG_189...
# Processing No.516, ZG_190...
# Processing No.517, ZG_191...
# Processing No.518, ZG_192...
# Processing No.519, ZG_193...
# Processing No.520, ZG_194...
# Processing No.521, ZG_195...
# Processing No.522, ZG_196...
# Processing No.523, ZG_197...
# Processing No.524, ZG_198...
# Processing No.525, ZG_199...
# Processing No.526, ZG_200...
# Processing No.527, ZG_201...
# Processing No.528, ZG_202...
# Processing No.529, ZG_203...
# Processing No.530, ZG_204...
# Processing No.531, ZG_205...
# Processing No.532, ZG_206...
# Processing No.533, ZG_207...
# Processing No.534, ZG_208...
# Processing No.535, ZG_209...
# Processing No.536, ZG_210...
# Processing No.537, ZG_211...
# Processing No.538, ZG_212...
# Processing No.539, ZG_213...
# Processing No.540, ZG_214...
# Processing No.541, ZG_215...
# Processing No.542, ZG_216...
# Processing No.543, ZG_217...
# Processing No.544, ZG_218...
# Processing No.545, ZG_219...
# Processing No.546, ZG_220...
# Processing No.547, ZG_221...
# Processing No.548, ZG_222...
# Processing No.549, ZG_223...
# Processing No.550, ZG_224...
# Processing No.551, ZG_225...
# Processing No.552, ZG_226...
# Processing No.553, ZG_227...
# Processing No.554, ZG_228...
# Processing No.555, ZG_229...
# Processing No.556, ZG_230...
# Processing No.557, ZG_231...
# Processing No.558, ZG_232...
# Processing No.559, ZG_233...
# Processing No.560, ZG_234...
# Processing No.561, ZG_235...
# Processing No.562, ZG_236...
# Processing No.563, ZG_237...
# Processing No.564, ZG_238...
# Processing No.565, ZG_239...
# Processing No.566, ZG_240...
# Processing No.567, ZG_241...
# Processing No.568, ZG_243...
# Processing No.569, ZG_244...
# Processing No.570, ZG_245...
# Processing No.571, ZG_246...
# Processing No.572, ZG_247...
# Processing No.573, ZG_248...
# Processing No.574, ZG_249...
# Processing No.575, ZG_250...
# Processing No.576, ZG_251...
# Processing No.577, ZG_252...
# Processing No.578, ZG_253...
# Processing No.579, ZG_254...
# Processing No.580, ZG_255...
# Processing No.581, ZG_256...
# Processing No.582, ZG_257...
# Processing No.583, ZG_258...
# Processing No.584, 4118850...
# Processing No.585, 4146360...
# Processing No.586, 4146400...
# Processing No.587, 4150280...
# Processing No.588, 4150282...
# Processing No.589, 4150310...
# Processing No.590, 4150315...
# Processing No.591, 4150331...
# Processing No.592, 4150465...
# Processing No.593, 4150475...
# Processing No.594, 4150500...
# Processing No.595, 4150501...
# Processing No.596, 4150505...
# Processing No.597, 4150507...
# Processing No.598, 4150509...
# Processing No.599, 4150600...
# Processing No.600, 4150605...
# Processing No.601, 4150680...
# Processing No.602, 4150681...
# Processing No.603, 4150700...
# Processing No.604, 4151511...
# Processing No.605, 4151600...
# Processing No.606, 4151650...
# Processing No.607, 4151800...
# Processing No.608, 4151801...
# Processing No.609, 4151803...
# Processing No.610, 4152200...
# Processing No.611, 4152465...
# Processing No.612, 4152500...
# Processing No.613, 4152590...
# Processing No.614, 4152600...
# Processing No.615, 4152610...
# Processing No.616, 4152620...
# Processing No.617, 4152660...
# Processing No.618, 4152701...
# Processing No.619, 4152800...
# Processing No.620, 4152900...
# Processing No.621, 4351130...
# Processing No.622, 4351410...
# Processing No.623, 4355050...
# Processing No.624, 4355080...
# Processing No.625, 4355100...
# Processing No.626, 4355110...
# Processing No.627, 4355280...
# Processing No.628, 4355310...
# Processing No.629, 4355320...
# Processing No.630, 4355340...
# Processing No.631, 4355400...
# Processing No.632, 4355500...
# Processing No.633, 4355600...
# Processing No.634, 4355700...
# Processing No.635, 4355750...
# Processing No.636, 4355950...
# Processing No.637, 4358050...
# Processing No.638, 4358210...
# Processing No.639, 4358300...
# Processing No.640, 4358320...
# Processing No.641, 4358500...
# Processing No.642, 4358530...
# Processing No.643, 4358600...
# Processing No.644, 4358800...
# Processing No.645, 4362110...
# Processing No.646, 4362600...
# Processing No.647, 4568150...
# Processing No.648, 4664800...
# Processing No.649, 4769250...
# Processing No.650, 4772210...
# Processing No.651, MX_0000054...
# Processing No.652, US_0006086...
# Processing No.653, US_0006257...
# Processing No.654, US_0006266...
# Processing No.655, US_0006277...
# Processing No.656, US_0006304...
# Processing No.657, US_0006317...
# Processing No.658, US_0006412...
# Processing No.659, US_0006804...
# Processing No.660, US_0006902...
# Processing No.661, US_0007144...
# Processing No.662, US_0007778...
# Processing No.663, US_0007856...
# Processing No.664, US_0007878...
# Processing No.665, 4103500...
# Processing No.666, 4103710...
# Processing No.667, 4103750...
# Processing No.668, 4103800...
# Processing No.669, 4103820...
# Processing No.670, 4105310...
# Processing No.671, 4105700...
# Processing No.672, 4115080...
# Processing No.673, 4115100...
# Processing No.674, 4115210...
# Processing No.675, 4115221...
# Processing No.676, 4115225...
# Processing No.677, 4115231...
# Processing No.678, 4115235...
# Processing No.679, 4115240...
# Processing No.680, 4115250...
# Processing No.681, 4115260...
# Processing No.682, 4115282...
# Processing No.683, 4115290...
# Processing No.684, 4115300...
# Processing No.685, 4115311...
# Processing No.686, 4115320...
# Processing No.687, 4115346...
# Processing No.688, 4115349...
# Processing No.689, 4115400...
# Processing No.690, 4115450...
# Processing No.691, 4116190...
# Processing No.692, 4116191...
# Processing No.693, 4116200...
# Processing No.694, 4116300...
# Processing No.695, 4116330...
# Processing No.696, 4116332...
# Processing No.697, 4116340...
# Processing No.698, 4116350...
# Processing No.699, 4116451...
# Processing No.700, 4118105...
# Processing No.701, 4120110...
# Processing No.702, 4120121...
# Processing No.703, 4120200...
# Processing No.704, 4120202...
# Processing No.705, 4120301...
# Processing No.706, 4120311...
# Processing No.707, 4120320...
# Processing No.708, 4120903...
# Processing No.709, 4120951...
# Processing No.710, 4122151...
# Processing No.711, 4146111...
# Processing No.712, 4146115...
# Processing No.713, 4146160...
# Processing No.714, 4146180...
# Processing No.715, 4146210...
# Processing No.716, 4146270...
# Processing No.717, 4146281...
# Processing No.718, 4146650...
# Processing No.719, 4146670...
# Processing No.720, 4203051...
# Processing No.721, 4203165...
# Processing No.722, 4203210...
# Processing No.723, 4203220...
# Processing No.724, 4203250...
# Processing No.725, 4203300...
# Processing No.726, 4203400...
# Processing No.727, 4203410...
# Processing No.728, 4203500...
# Processing No.729, 4203510...
# Processing No.730, 4203770...
# Processing No.731, 4203910...
# Processing No.732, 4204100...
# Processing No.733, 4206600...
# Processing No.734, 4207100...
# Processing No.735, 4207150...
# Processing No.736, 4207250...
# Processing No.737, 4207305...
# Processing No.738, 4207320...
# Processing No.739, 4207800...
# Processing No.740, 4207900...
# Processing No.741, 4208041...
# Processing No.742, 4208065...
# Processing No.743, 4208100...
# Processing No.744, 4208159...
# Processing No.745, 4208160...
# Processing No.746, 4208168...
# Processing No.747, 4208170...
# Processing No.748, 4208200...
# Processing No.749, 4208220...
# Processing No.750, 4208221...
# Processing No.751, 4208225...
# Processing No.752, 4208240...
# Processing No.753, 4208245...
# Processing No.754, 4208251...
# Processing No.755, 4208256...
# Processing No.756, 4208260...
# Processing No.757, 4208271...
# Processing No.758, 4208275...
# Processing No.759, 4208280...
# Processing No.760, 4208285...
# Processing No.761, 4208290...
# Processing No.762, 4208295...
# Processing No.763, 4208311...
# Processing No.764, 4208330...
# Processing No.765, 4208335...
# Processing No.766, 4208350...
# Processing No.767, 4208357...
# Processing No.768, 4208360...
# Processing No.769, 4208365...
# Processing No.770, 4208371...
# Processing No.771, 4208386...
# Processing No.772, 4208395...
# Processing No.773, 4208410...
# Processing No.774, 4208420...
# Processing No.775, 4208427...
# Processing No.776, 4208440...
# Processing No.777, 4208461...
# Processing No.778, 4208470...
# Processing No.779, 4208477...
# Processing No.780, 4208505...
# Processing No.781, 4208510...
# Processing No.782, 4208516...
# Processing No.783, 4208520...
# Processing No.784, 4208536...
# Processing No.785, 4208561...
# Processing No.786, 4208565...
# Processing No.787, 4208570...
# Processing No.788, 4208580...
# Processing No.789, 4208596...
# Processing No.790, 4208630...
# Processing No.791, 4208640...
# Processing No.792, 4208641...
# Processing No.793, 4208645...
# Processing No.794, 4208649...
# Processing No.795, 4208733...
# Processing No.796, 4208734...
# Processing No.797, 4208770...
# Processing No.798, 4208792...
# Processing No.799, 4208821...
# Processing No.800, 4208835...
# Processing No.801, 4208843...
# Processing No.802, 4208857...
# Processing No.803, 4208880...
# Processing No.804, 4208890...
# Processing No.805, 4208895...
# Processing No.806, 4208916...
# Processing No.807, 4208947...
# Processing No.808, 4208960...
# Processing No.809, 4208962...
# Processing No.810, 4208971...
# Processing No.811, 4208983...
# Processing No.812, 4208986...
# Processing No.813, 4208987...
# Processing No.814, 4208988...
# Processing No.815, 4209150...
# Processing No.816, 4209500...
# Processing No.817, 4209806...
# Processing No.818, 4209810...
# Processing No.819, 4213045...
# Processing No.820, 4213050...
# Processing No.821, 4213101...
# Processing No.822, 4213111...
# Processing No.823, 4213131...
# Processing No.824, 4213134...
# Processing No.825, 4213250...
# Processing No.826, 4213300...
# Processing No.827, 4213315...
# Processing No.828, 4213375...
# Processing No.829, 4213400...
# Processing No.830, 4213562...
# Processing No.831, 4213563...
# Processing No.832, 4213835...
# Processing No.833, 4214210...
# Processing No.834, 4214220...
# Processing No.835, 4214264...
# Processing No.836, 4214286...
# Processing No.837, 4214290...
# Processing No.838, 4214295...
# Processing No.839, 4214297...
# Processing No.840, 4214298...
# Processing No.841, 4215260...
# Processing No.842, 4215660...
# Processing No.843, 4245295...
# Processing No.844, 4245500...
# Processing No.845, CA_0004367...
# Processing No.846, CA_0004386...
# Processing No.847, CA_0004433...
# Processing No.848, CA_0004436...
# Processing No.849, CA_0004868...
# Processing No.850, CA_0005306...
# Processing No.851, CA_0005316...
# Processing No.852, CA_0005614...
# Processing No.853, US_0007357...
# Processing No.854, US_0007462...
# Processing No.855, US_0007958...
# Processing No.856, US_0007968...
# Processing No.857, US_0008058...
# Processing No.858, US_0008445...
# Processing No.859, US_0008474...
# Processing No.860, US_0008482...
# Processing No.861, US_0008611...
# Processing No.862, US_0008617...
# Processing No.863, US_0008687...
# Processing No.864, US_0008718...
# Processing No.865, US_0008734...
# Processing No.866, US_0008738...
# Processing No.867, US_0008764...
# Processing No.868, US_0008981...
# Processing No.869, 4113600...
# Processing No.870, 4114615...
# Processing No.871, 4119050...
# Processing No.872, 4119070...
# Processing No.873, 4119080...
# Processing No.874, 4119100...
# Processing No.875, 4119101...
# Processing No.876, 4119150...
# Processing No.877, 4119170...
# Processing No.878, 4119200...
# Processing No.879, 4119230...
# Processing No.880, 4119250...
# Processing No.881, 4119270...
# Processing No.882, 4119280...
# Processing No.883, 4119290...
# Processing No.884, 4119400...
# Processing No.885, 4119430...
# Processing No.886, 4119440...
# Processing No.887, 4119450...
# Processing No.888, 4119460...
# Processing No.889, 4119510...
# Processing No.890, 4119650...
# Processing No.891, 4122251...
# Processing No.892, 4123062...
# Processing No.893, 4123080...
# Processing No.894, 4123081...
# Processing No.895, 4123095...
# Processing No.896, 4123111...
# Processing No.897, 4123130...
# Processing No.898, 4123206...
# Processing No.899, 4123225...
# Processing No.900, 4123230...
# Processing No.901, 4123240...
# Processing No.902, 4123250...
# Processing No.903, 4123260...
# Processing No.904, 4123280...
# Processing No.905, 4123290...
# Processing No.906, 4123320...
# Processing No.907, 4123350...
# Processing No.908, 4123352...
# Processing No.909, 4123355...
# Processing No.910, 4123400...
# Processing No.911, 4127150...
# Processing No.912, 4127200...
# Processing No.913, 4127400...
# Processing No.914, 4127600...
# Processing No.915, 4127700...
# Processing No.916, 4131030...
# Processing No.917, 4131031...
# Processing No.918, 4132200...
# Processing No.919, 4133200...
# Processing No.920, 4133401...
# Processing No.921, 4133500...
# Processing No.922, 4133651...
# Processing No.923, 4133750...
# Processing No.924, 4134300...
# Processing No.925, 4134501...
# Processing No.926, 4135200...
# Processing No.927, 4135210...
# Processing No.928, 4136300...
# Processing No.929, 4136400...
# Processing No.930, 4136500...
# Processing No.931, 4143310...
# Processing No.932, 4143500...
# Processing No.933, 4147010...
# Processing No.934, 4147110...
# Processing No.935, 4147320...
# Processing No.936, 4147340...
# Processing No.937, 4147380...
# Processing No.938, 4147450...
# Processing No.939, 4147460...
# Processing No.940, 4147490...
# Processing No.941, 4147500...
# Processing No.942, 4147600...
# Processing No.943, 4147651...
# Processing No.944, 4147703...
# Processing No.945, 4147704...
# Processing No.946, 4147720...
# Processing No.947, 4147725...
# Processing No.948, 4147901...
# Processing No.949, 4147905...
# Processing No.950, 4147907...
# Processing No.951, 4147950...
# Processing No.952, 4148070...
# Processing No.953, 4148090...
# Processing No.954, 4148110...
# Processing No.955, 4148121...
# Processing No.956, 4148125...
# Processing No.957, 4148231...
# Processing No.958, 4148300...
# Processing No.959, 4148310...
# Processing No.960, 4148530...
# Processing No.961, 4148541...
# Processing No.962, 4148570...
# Processing No.963, 4148610...
# Processing No.964, 4148650...
# Processing No.965, 4148720...
# Processing No.966, 4148750...
# Processing No.967, 4149110...
# Processing No.968, 4149120...
# Processing No.969, 4149350...
# Processing No.970, 4149360...
# Processing No.971, 4149400...
# Processing No.972, 4149405...
# Processing No.973, 4149413...
# Processing No.974, 4149420...
# Processing No.975, 4149440...
# Processing No.976, 4149610...
# Processing No.977, 4149630...
# Processing No.978, 4149690...
# Processing No.979, 4149710...
# Processing No.980, 4149780...
# Processing No.981, 4149810...
# Processing No.982, 4149850...
# Processing No.983, 4149941...
# Processing No.984, 4149950...
# Processing No.985, 4149955...
# Processing No.986, 4213211...
# Processing No.987, 4213415...
# Processing No.988, 4213730...
# Processing No.989, 4213740...
# Processing No.990, 4213745...
# Processing No.991, 4213804...
# Processing No.992, 4213880...
# Processing No.993, 4213890...
# Processing No.994, 4213911...
# Processing No.995, 4213945...
# Processing No.996, 4213956...
# Processing No.997, 4214025...
# Processing No.998, 4214035...
# Processing No.999, 4214040...
# Processing No.1000, 4214080...
# Processing No.1001, 4214351...
# Processing No.1002, 4214440...
# Processing No.1003, 4214450...
# Processing No.1004, 4214460...
# Processing No.1005, 4214475...
# Processing No.1006, 4214513...
# Processing No.1007, 4214517...
# Processing No.1008, 4214519...
# Processing No.1009, 4214520...
# Processing No.1010, 4214530...
# Processing No.1011, 4214540...
# Processing No.1012, 4214555...
# Processing No.1013, 4214560...
# Processing No.1014, 4214570...
# Processing No.1015, 4214580...
# Processing No.1016, 4214610...
# Processing No.1017, 4214621...
# Processing No.1018, 4214655...
# Processing No.1019, 4214670...
# Processing No.1020, 4214680...
# Processing No.1021, 4214690...
# Processing No.1022, 4214700...
# Processing No.1023, 4214750...
# Processing No.1024, 4214760...
# Processing No.1025, 4214775...
# Processing No.1026, 4214801...
# Processing No.1027, 4214810...
# Processing No.1028, 4214830...
# Processing No.1029, 4214900...
# Processing No.1030, 4214920...
# Processing No.1031, 4214930...
# Processing No.1032, 4214940...
# Processing No.1033, 4231250...
# Processing No.1034, 4231600...
# Processing No.1035, 4231610...
# Processing No.1036, 4231620...
# Processing No.1037, 4231650...
# Processing No.1038, 4232700...
# Processing No.1039, 4234300...
# Processing No.1040, 4234400...
# Processing No.1041, 4235101...
# Processing No.1042, 4235300...
# Processing No.1043, 4236600...
# Processing No.1044, 4243080...
# Processing No.1045, 4243101...
# Processing No.1046, 4243215...
# Processing No.1047, 4243240...
# Processing No.1048, 4243270...
# Processing No.1049, 4243300...
# Processing No.1050, 4243301...
# Processing No.1051, 4243360...
# Processing No.1052, 4244430...
# Processing No.1053, 4244450...
# Processing No.1054, 4244460...
# Processing No.1055, 4244500...
# Processing No.1056, 4244550...
# Processing No.1057, 4244600...
# Processing No.1058, 4244630...
# Processing No.1059, 4244635...
# Processing No.1060, 4244660...
# Processing No.1061, 4244880...
# Processing No.1062, 4244890...
# Processing No.1063, 4244940...
# Processing No.1064, 4247100...
# Processing No.1065, CA_0000018...
# Processing No.1066, CA_0001011...
# Processing No.1067, CA_0001029...
# Processing No.1068, CA_0001048...
# Processing No.1069, CA_0001059...
# Processing No.1070, CA_0001071...
# Processing No.1071, CA_0001139...
# Processing No.1072, US_0000001...
# Processing No.1073, US_0001652...
# Processing No.1074, US_0001672...
# Processing No.1075, US_0001677...
# Processing No.1076, US_0002188...
# Processing No.1077, US_0002346...
# Processing No.1078, US_0002404...
# Processing No.1079, US_0002521...
# Processing No.1080, US_0002572...
# Processing No.1081, US_0002582...
# Processing No.1082, US_0002586...
# Processing No.1083, US_0002614...
# Processing No.1084, US_0002664...
# Processing No.1085, US_0002761...
# Processing No.1086, US_0002852...
# Processing No.1087, US_0003918...
# Processing No.1088, US_0003933...
# Processing No.1089, US_0003937...
# Processing No.1090, US_0003950...
# Processing No.1091, US_0005790...
# Processing No.1092, 4113300...
# Processing No.1093, 4113301...
# Processing No.1094, 4113303...
# Processing No.1095, 4113306...
# Processing No.1096, 4113307...
# Processing No.1097, 4113308...
# Processing No.1098, 4113321...
# Processing No.1099, 4113350...
# Processing No.1100, 4113361...
# Processing No.1101, 4113365...
# Processing No.1102, 4113401...
# Processing No.1103, 4113420...
# Processing No.1104, 4120100...
# Processing No.1105, 4120950...
# Processing No.1106, 4121100...
# Processing No.1107, 4121110...
# Processing No.1108, 4121120...
# Processing No.1109, 4121131...
# Processing No.1110, 4121146...
# Processing No.1111, 4121160...
# Processing No.1112, 4121161...
# Processing No.1113, 4121300...
# Processing No.1114, 4121320...
# Processing No.1115, 4121330...
# Processing No.1116, 4121341...
# Processing No.1117, 4121350...
# Processing No.1118, 4121400...
# Processing No.1119, 4121420...
# Processing No.1120, 4121430...
# Processing No.1121, 4122100...
# Processing No.1122, 4122105...
# Processing No.1123, 4122120...
# Processing No.1124, 4122155...
# Processing No.1125, 4122160...
# Processing No.1126, 4122170...
# Processing No.1127, 4122180...
# Processing No.1128, 4122190...
# Processing No.1129, 4122201...
# Processing No.1130, 4122222...
# Processing No.1131, 4122260...
# Processing No.1132, 4122281...
# Processing No.1133, 4122300...
# Processing No.1134, 4122350...
# Processing No.1135, 4122600...
# Processing No.1136, 4122700...
# Processing No.1137, 4125010...
# Processing No.1138, 4125028...
# Processing No.1139, 4125050...
# Processing No.1140, 4125060...
# Processing No.1141, 4125070...
# Processing No.1142, 4125200...
# Processing No.1143, 4125500...
# Processing No.1144, 4125550...
# Processing No.1145, 4125801...
# Processing No.1146, 4125810...
# Processing No.1147, 4125901...
# Processing No.1148, 4125942...
# Processing No.1149, 4126100...
# Processing No.1150, 4126300...
# Processing No.1151, 4126350...
# Processing No.1152, 4126701...
# Processing No.1153, 4126750...
# Processing No.1154, 4126800...
# Processing No.1155, 4126804...
# Processing No.1156, 4126810...
# Processing No.1157, 4126851...
# Processing No.1158, 4127100...
# Processing No.1159, 4150800...
# Processing No.1160, 4213025...
# Processing No.1161, 4213201...
# Processing No.1162, 4213203...
# Processing No.1163, 4213205...
# Processing No.1164, 4213410...
# Processing No.1165, 4213435...
# Processing No.1166, 4213440...
# Processing No.1167, 4213510...
# Processing No.1168, 4213531...
# Processing No.1169, 4213540...
# Processing No.1170, 4213550...
# Processing No.1171, 4213571...
# Processing No.1172, 4213590...
# Processing No.1173, 4213596...
# Processing No.1174, 4213601...
# Processing No.1175, 4213683...
# Processing No.1176, 4213690...
# Processing No.1177, 4213715...
# Processing No.1178, 4213810...
# Processing No.1179, 4213840...
# Processing No.1180, 4213845...
# Processing No.1181, 4213935...
# Processing No.1182, 4214010...
# Processing No.1183, 4214050...
# Processing No.1184, 4214090...
# Processing No.1185, 4214091...
# Processing No.1186, 4214100...
# Processing No.1187, 4214105...
# Processing No.1188, 4214275...
# Processing No.1189, 4214280...
# Processing No.1190, 4214281...
# Processing No.1191, US_0004584...
# Processing No.1192, US_0004591...
# Processing No.1193, US_0004872...
# Processing No.1194, US_0004997...
# Processing No.1195, US_0005562...
# Processing No.1196, US_0005571...
# Processing No.1197, US_0005820...
# Processing No.1198, US_0005826...
# Processing No.1199, US_0005885...
# Processing No.1200, US_0005902...
# Processing No.1201, US_0005930...
# Processing No.1202, 3103300...
# Processing No.1203, 3179010...
# Processing No.1204, 3179330...
# Processing No.1205, 3179500...
# Processing No.1206, 3179590...
# Processing No.1207, 3206720...
# Processing No.1208, 3264500...
# Processing No.1209, 3265040...
# Processing No.1210, 3268500...
# Processing No.1211, 3268900...
# Processing No.1212, 3274150...
# Processing No.1213, 3275140...
# Processing No.1214, 3275290...
# Processing No.1215, 3275400...
# Processing No.1216, 3275700...
# Processing No.1217, 3275750...
# Processing No.1218, 3275800...
# Processing No.1219, 3275900...
# Processing No.1220, 3275990...
# Processing No.1221, 3276200...
# Processing No.1222, 3469100...
# Processing No.1223, 3512400...
# Processing No.1224, 3514800...
# Processing No.1225, 3613050...
# Processing No.1226, 3613060...
# Processing No.1227, 3617805...
# Processing No.1228, 3617811...
# Processing No.1229, 3617812...
# Processing No.1230, 3618051...
# Processing No.1231, 3618053...
# Processing No.1232, 3618090...
# Processing No.1233, 3618110...
# Processing No.1234, 3618120...
# Processing No.1235, 3618130...
# Processing No.1236, 3618150...
# Processing No.1237, 3618200...
# Processing No.1238, 3618500...
# Processing No.1239, 3618720...
# Processing No.1240, 3618951...
# Processing No.1241, 3624200...
# Processing No.1242, 3624400...
# Processing No.1243, 3624500...
# Processing No.1244, 3628400...
# Processing No.1245, 3628700...
# Processing No.1246, 3628900...
# Processing No.1247, 3630100...
# Processing No.1248, 3630300...
# Processing No.1249, 3630600...
# Processing No.1250, 3631100...
# Processing No.1251, 3631110...
# Processing No.1252, 3631210...
# Processing No.1253, 3631215...
# Processing No.1254, 3631500...
# Processing No.1255, 3632400...
# Processing No.1256, 3632401...
# Processing No.1257, 3632801...
# Processing No.1258, 3633120...
# Processing No.1259, 3633122...
# Processing No.1260, 3633123...
# Processing No.1261, 3633160...
# Processing No.1262, 3633300...
# Processing No.1263, 3633301...
# Processing No.1264, 3633310...
# Processing No.1265, 3634160...
# Processing No.1266, 3634200...
# Processing No.1267, 3634210...
# Processing No.1268, 3634220...
# Processing No.1269, 3634320...
# Processing No.1270, 3634340...
# Processing No.1271, 3634350...
# Processing No.1272, 3634360...
# Processing No.1273, 3634370...
# Processing No.1274, 3634380...
# Processing No.1275, 3634500...
# Processing No.1276, 3635040...
# Processing No.1277, 3635301...
# Processing No.1278, 3635310...
# Processing No.1279, 3635402...
# Processing No.1280, 3635408...
# Processing No.1281, 3635430...
# Processing No.1282, 3635440...
# Processing No.1283, 3635450...
# Processing No.1284, 3635551...
# Processing No.1285, 3635651...
# Processing No.1286, 3635660...
# Processing No.1287, 3636202...
# Processing No.1288, 3636500...
# Processing No.1289, 3637152...
# Processing No.1290, 3637180...
# Processing No.1291, 3637380...
# Processing No.1292, 3637772...
# Processing No.1293, 3637790...
# Processing No.1294, 3637900...
# Processing No.1295, 3637910...
# Processing No.1296, 3638010...
# Processing No.1297, 3638050...
# Processing No.1298, 3638051...
# Processing No.1299, 3638120...
# Processing No.1300, 3638150...
# Processing No.1301, 3638200...
# Processing No.1302, 3638210...
# Processing No.1303, 3649012...
# Processing No.1304, 3649030...
# Processing No.1305, 3649150...
# Processing No.1306, 3649211...
# Processing No.1307, 3649240...
# Processing No.1308, 3649251...
# Processing No.1309, 3649310...
# Processing No.1310, 3649320...
# Processing No.1311, 3649411...
# Processing No.1312, 3649418...
# Processing No.1313, 3649449...
# Processing No.1314, 3649459...
# Processing No.1315, 3649460...
# Processing No.1316, 3649510...
# Processing No.1317, 3649617...
# Processing No.1318, 3649619...
# Processing No.1319, 3649640...
# Processing No.1320, 3649850...
# Processing No.1321, 3649855...
# Processing No.1322, 3649902...
# Processing No.1323, 3649906...
# Processing No.1324, 3649950...
# Processing No.1325, 3649960...
# Processing No.1326, 3650150...
# Processing No.1327, 3650202...
# Processing No.1328, 3650221...
# Processing No.1329, 3650270...
# Processing No.1330, 3650285...
# Processing No.1331, 3650359...
# Processing No.1332, 3650385...
# Processing No.1333, 3650470...
# Processing No.1334, 3650477...
# Processing No.1335, 3650481...
# Processing No.1336, 3650488...
# Processing No.1337, 3650510...
# Processing No.1338, 3650525...
# Processing No.1339, 3650649...
# Processing No.1340, 3650745...
# Processing No.1341, 3650750...
# Processing No.1342, 3650912...
# Processing No.1343, 3650940...
# Processing No.1344, 3651309...
# Processing No.1345, 3651408...
# Processing No.1346, 3651520...
# Processing No.1347, 3651530...
# Processing No.1348, 3651535...
# Processing No.1349, 3651650...
# Processing No.1350, 3651660...
# Processing No.1351, 3651670...
# Processing No.1352, 3651678...
# Processing No.1353, 3651800...
# Processing No.1354, 3651805...
# Processing No.1355, 3651900...
# Processing No.1356, 3652010...
# Processing No.1357, 3652050...
# Processing No.1358, 3652089...
# Processing No.1359, 3652130...
# Processing No.1360, 3652220...
# Processing No.1361, 3652320...
# Processing No.1362, 3652455...
# Processing No.1363, 3652500...
# Processing No.1364, 3652850...
# Processing No.1365, 3652879...
# Processing No.1366, 3652890...
# Processing No.1367, 3653120...
# Processing No.1368, 3653352...
# Processing No.1369, 3653450...
# Processing No.1370, 3653710...
# Processing No.1371, 3660109...
# Processing No.1372, 3662400...
# Processing No.1373, 3662550...
# Processing No.1374, 3662655...
# Processing No.1375, 3663700...
# Processing No.1376, 3663800...
# Processing No.1377, 3664100...
# Processing No.1378, 3664160...
# Processing No.1379, 3664800...
# Processing No.1380, 3664802...
# Processing No.1381, 3664905...
# Processing No.1382, 3666050...
# Processing No.1383, 3666200...
# Processing No.1384, 3666400...
# Processing No.1385, 3666401...
# Processing No.1386, 3666600...
# Processing No.1387, 3666700...
# Processing No.1388, 3669050...
# Processing No.1389, 3669310...
# Processing No.1390, 3669520...
# Processing No.1391, 3669600...
# Processing No.1392, 3669630...
# Processing No.1393, 3669700...
# Processing No.1394, 3671810...
# Processing No.1395, 3754300...
# Processing No.1396, 3844100...
# Processing No.1397, 3844400...
# Processing No.1398, 3844450...
# Processing No.1399, 3844465...
# Processing No.1400, 3948350...
# Processing No.1401, 3948800...
# Processing No.1402, BR_0000017...
# Processing No.1403, BR_0000112...
# Processing No.1404, BR_0000143...
# Processing No.1405, BR_0000155...
# Processing No.1406, BR_0000158...
# Processing No.1407, BR_0000311...
# Processing No.1408, BR_0000933...
# Processing No.1409, BR_0000936...
# Processing No.1410, BR_0000999...
# Processing No.1411, BR_0001015...
# Processing No.1412, BR_0001042...
# Processing No.1413, BR_0001073...
# Processing No.1414, BR_0001133...
# Processing No.1415, BR_0001170...
# Processing No.1416, BR_0001333...
# Processing No.1417, BR_0001460...
# Processing No.1418, BR_0001481...
# Processing No.1419, BR_0001497...
# Processing No.1420, BR_0001506...
# Processing No.1421, BR_0001722...
# Processing No.1422, BR_0001729...
# Processing No.1423, BR_0001732...
# Processing No.1424, BR_0001738...
# Processing No.1425, BR_0001755...
# Processing No.1426, BR_0001827...
# Processing No.1427, BR_0001830...
# Processing No.1428, BR_0001848...
# Processing No.1429, BR_0001862...
# Processing No.1430, BR_0001870...
# Processing No.1431, BR_0001877...
# Processing No.1432, BR_0001879...
# Processing No.1433, BR_0001880...
# Processing No.1434, BR_0001884...
# Processing No.1435, BR_0001888...
# Processing No.1436, BR_0001906...
# Processing No.1437, BR_0001924...
# Processing No.1438, BR_0001935...
# Processing No.1439, BR_0002002...
# Processing No.1440, BR_0002025...
# Processing No.1441, BR_0002088...
# Processing No.1442, BR_0002163...
# Processing No.1443, BR_0002178...
# Processing No.1444, BR_0002210...
# Processing No.1445, BR_0002249...
# Processing No.1446, BR_0002261...
# Processing No.1447, BR_0002268...
# Processing No.1448, BR_0002273...
# Processing No.1449, BR_0002277...
# Processing No.1450, BR_0002323...
# Processing No.1451, BR_0002432...
# Processing No.1452, BR_0002446...
# Processing No.1453, BR_0002675...
# Processing No.1454, BR_0002742...
# Processing No.1455, BR_0002746...
# Processing No.1456, BR_0002747...
# Processing No.1457, BR_0002754...
# Processing No.1458, BR_0002777...
# Processing No.1459, BR_0002805...
# Processing No.1460, BR_0002828...
# Processing No.1461, BR_0002837...
# Processing No.1462, BR_0002891...
# Processing No.1463, BR_0002913...
# Processing No.1464, BR_0002924...
# Processing No.1465, BR_0002927...
# Processing No.1466, BR_0002949...
# Processing No.1467, BR_0002952...
# Processing No.1468, BR_0002984...
# Processing No.1469, BR_0003223...
# Processing No.1470, BR_0003250...
# Processing No.1471, 6112090...
# Processing No.1472, 6113100...
# Processing No.1473, 6116200...
# Processing No.1474, 6119010...
# Processing No.1475, 6119200...
# Processing No.1476, 6119240...
# Processing No.1477, 6122110...
# Processing No.1478, 6122141...
# Processing No.1479, 6122300...
# Processing No.1480, 6123100...
# Processing No.1481, 6123180...
# Processing No.1482, 6123210...
# Processing No.1483, 6123250...
# Processing No.1484, 6123370...
# Processing No.1485, 6123400...
# Processing No.1486, 6123710...
# Processing No.1487, 6124501...
# Processing No.1488, 6125360...
# Processing No.1489, 6128701...
# Processing No.1490, 6139100...
# Processing No.1491, 6139284...
# Processing No.1492, 6139391...
# Processing No.1493, 6139682...
# Processing No.1494, 6139770...
# Processing No.1495, 6139850...
# Processing No.1496, 6140250...
# Processing No.1497, 6140300...
# Processing No.1498, 6140450...
# Processing No.1499, 6140480...
# Processing No.1500, 6142120...
# Processing No.1501, 6142150...
# Processing No.1502, 6142520...
# Processing No.1503, 6142600...
# Processing No.1504, 6142620...
# Processing No.1505, 6144200...
# Processing No.1506, 6144300...
# Processing No.1507, 6172011...
# Processing No.1508, 6172016...
# Processing No.1509, 6172023...
# Processing No.1510, 6172036...
# Processing No.1511, 6172050...
# Processing No.1512, 6172200...
# Processing No.1513, 6172351...
# Processing No.1514, 6210310...
# Processing No.1515, 6211100...
# Processing No.1516, 6211160...
# Processing No.1517, 6211500...
# Processing No.1518, 6212410...
# Processing No.1519, 6212470...
# Processing No.1520, 6212510...
# Processing No.1521, 6212710...
# Processing No.1522, 6212750...
# Processing No.1523, 6212780...
# Processing No.1524, 6212850...
# Processing No.1525, 6213780...
# Processing No.1526, 6213800...
# Processing No.1527, 6216700...
# Processing No.1528, 6216810...
# Processing No.1529, 6217100...
# Processing No.1530, 6217500...
# Processing No.1531, 6220162...
# Processing No.1532, 6220300...
# Processing No.1533, 6220361...
# Processing No.1534, 6221550...
# Processing No.1535, 6221680...
# Processing No.1536, 6226200...
# Processing No.1537, 6226310...
# Processing No.1538, 6226600...
# Processing No.1539, 6226650...
# Processing No.1540, 6226800...
# Processing No.1541, 6229100...
# Processing No.1542, 6232910...
# Processing No.1543, 6232911...
# Processing No.1544, 6232930...
# Processing No.1545, 6233100...
# Processing No.1546, 6233110...
# Processing No.1547, 6233112...
# Processing No.1548, 6233114...
# Processing No.1549, 6233124...
# Processing No.1550, 6233130...
# Processing No.1551, 6233150...
# Processing No.1552, 6233163...
# Processing No.1553, 6233170...
# Processing No.1554, 6233221...
# Processing No.1555, 6233233...
# Processing No.1556, 6233250...
# Processing No.1557, 6233360...
# Processing No.1558, 6233400...
# Processing No.1559, 6233410...
# Processing No.1560, 6233412...
# Processing No.1561, 6233414...
# Processing No.1562, 6233501...
# Processing No.1563, 6233510...
# Processing No.1564, 6233650...
# Processing No.1565, 6233700...
# Processing No.1566, 6233710...
# Processing No.1567, 6233720...
# Processing No.1568, 6233780...
# Processing No.1569, 6233850...
# Processing No.1570, 6242050...
# Processing No.1571, 6242150...
# Processing No.1572, 6242250...
# Processing No.1573, 6242630...
# Processing No.1574, 6242930...
# Processing No.1575, 6246110...
# Processing No.1576, 6246145...
# Processing No.1577, 6262300...
# Processing No.1578, 6335030...
# Processing No.1579, 6335045...
# Processing No.1580, 6335080...
# Processing No.1581, 6335115...
# Processing No.1582, 6335125...
# Processing No.1583, 6335304...
# Processing No.1584, 6335350...
# Processing No.1585, 6335600...
# Processing No.1586, 6336050...
# Processing No.1587, 6336800...
# Processing No.1588, 6336900...
# Processing No.1589, 6337060...
# Processing No.1590, 6337200...
# Processing No.1591, 6337502...
# Processing No.1592, 6337505...
# Processing No.1593, 6337506...
# Processing No.1594, 6337510...
# Processing No.1595, 6337513...
# Processing No.1596, 6337515...
# Processing No.1597, 6337516...
# Processing No.1598, 6338110...
# Processing No.1599, 6338160...
# Processing No.1600, 6338200...
# Processing No.1601, 6338250...
# Processing No.1602, 6340110...
# Processing No.1603, 6340120...
# Processing No.1604, 6340170...
# Processing No.1605, 6340200...
# Processing No.1606, 6340300...
# Processing No.1607, 6340500...
# Processing No.1608, 6340611...
# Processing No.1609, 6340620...
# Processing No.1610, 6340631...
# Processing No.1611, 6340700...
# Processing No.1612, 6341500...
# Processing No.1613, 6342130...
# Processing No.1614, 6342201...
# Processing No.1615, 6342502...
# Processing No.1616, 6342510...
# Processing No.1617, 6342610...
# Processing No.1618, 6342611...
# Processing No.1619, 6342620...
# Processing No.1620, 6342650...
# Processing No.1621, 6342820...
# Processing No.1622, 6343100...
# Processing No.1623, 6343500...
# Processing No.1624, 6348200...
# Processing No.1625, 6348300...
# Processing No.1626, 6348600...
# Processing No.1627, 6349300...
# Processing No.1628, 6357010...
# Processing No.1629, 6357500...
# Processing No.1630, 6357501...
# Processing No.1631, 6373300...
# Processing No.1632, 6421100...
# Processing No.1633, 6435060...
# Processing No.1634, 6444090...
# Processing No.1635, 6444100...
# Processing No.1636, 6444110...
# Processing No.1637, 6444380...
# Processing No.1638, 6444600...
# Processing No.1639, 6456107...
# Processing No.1640, 6456120...
# Processing No.1641, 6457200...
# Processing No.1642, 6457220...
# Processing No.1643, 6457330...
# Processing No.1644, 6457670...
# Processing No.1645, 6457690...
# Processing No.1646, 6457707...
# Processing No.1647, 6457720...
# Processing No.1648, 6457730...
# Processing No.1649, 6457800...
# Processing No.1650, 6457830...
# Processing No.1651, 6457850...
# Processing No.1652, 6457956...
# Processing No.1653, 6457990...
# Processing No.1654, 6458406...
# Processing No.1655, 6458460...
# Processing No.1656, 6458510...
# Processing No.1657, 6458540...
# Processing No.1658, 6458555...
# Processing No.1659, 6458560...
# Processing No.1660, 6458610...
# Processing No.1661, 6458715...
# Processing No.1662, 6458753...
# Processing No.1663, 6458863...
# Processing No.1664, 6458924...
# Processing No.1665, 6458940...
# Processing No.1666, 6458950...
# Processing No.1667, 6502141...
# Processing No.1668, 6502160...
# Processing No.1669, 6503100...
# Processing No.1670, 6503250...
# Processing No.1671, 6503280...
# Processing No.1672, 6503300...
# Processing No.1673, 6503352...
# Processing No.1674, 6503500...
# Processing No.1675, 6503851...
# Processing No.1676, 6545050...
# Processing No.1677, 6545700...
# Processing No.1678, 6545800...
# Processing No.1679, 6546610...
# Processing No.1680, 6547500...
# Processing No.1681, 6574152...
# Processing No.1682, 6574156...
# Processing No.1683, 6574300...
# Processing No.1684, 6574350...
# Processing No.1685, 6574360...
# Processing No.1686, 6574721...
# Processing No.1687, 6590700...
# Processing No.1688, 6603120...
# Processing No.1689, 6603300...
# Processing No.1690, 6604201...
# Processing No.1691, 6604220...
# Processing No.1692, 6604330...
# Processing No.1693, 6604360...
# Processing No.1694, 6605300...
# Processing No.1695, 6605420...
# Processing No.1696, 6605570...
# Processing No.1697, 6605615...
# Processing No.1698, 6605695...
# Processing No.1699, 6605750...
# Processing No.1700, 6605780...
# Processing No.1701, 6605830...
# Processing No.1702, 6605880...
# Processing No.1703, 6606600...
# Processing No.1704, 6606620...
# Processing No.1705, 6606650...
# Processing No.1706, 6607130...
# Processing No.1707, 6607225...
# Processing No.1708, 6607851...
# Processing No.1709, 6608170...
# Processing No.1710, 6608210...
# Processing No.1711, 6608501...
# Processing No.1712, 6609400...
# Processing No.1713, 6609500...
# Processing No.1714, 6646800...
# Processing No.1715, 6680600...
# Processing No.1716, 6729310...
# Processing No.1717, 6729371...
# Processing No.1718, 6729400...
# Processing No.1719, 6729401...
# Processing No.1720, 6729450...
# Processing No.1721, 6729453...
# Processing No.1722, 6729595...
# Processing No.1723, 6730100...
# Processing No.1724, 6730501...
# Processing No.1725, 6731020...
# Processing No.1726, 6731910...
# Processing No.1727, 6733570...
# Processing No.1728, 6742400...
# Processing No.1729, 6742450...
# Processing No.1730, 6742552...
# Processing No.1731, 6742600...
# Processing No.1732, 6742700...
# Processing No.1733, 6742701...
# Processing No.1734, 6742912...
# Processing No.1735, 6744100...
# Processing No.1736, 6781800...
# Processing No.1737, 6830102...
# Processing No.1738, 6830105...
# Processing No.1739, 6830511...
# Processing No.1740, 6830512...
# Processing No.1741, 6832750...
# Processing No.1742, 6842550...
# Processing No.1743, 6854101...
# Processing No.1744, 6854103...
# Processing No.1745, 6854105...
# Processing No.1746, 6854106...
# Processing No.1747, 6854116...
# Processing No.1748, 6854150...
# Processing No.1749, 6854200...
# Processing No.1750, 6854203...
# Processing No.1751, 6854205...
# Processing No.1752, 6854220...
# Processing No.1753, 6854250...
# Processing No.1754, 6854280...
# Processing No.1755, 6854301...
# Processing No.1756, 6854340...
# Processing No.1757, 6854400...
# Processing No.1758, 6854520...
# Processing No.1759, 6854591...
# Processing No.1760, 6854592...
# Processing No.1761, 6854600...
# Processing No.1762, 6854610...
# Processing No.1763, 6854620...
# Processing No.1764, 6854630...
# Processing No.1765, 6854650...
# Processing No.1766, 6854700...
# Processing No.1767, 6854705...
# Processing No.1768, 6854707...
# Processing No.1769, 6854708...
# Processing No.1770, 6854710...
# Processing No.1771, 6854712...
# Processing No.1772, 6854714...
# Processing No.1773, 6854720...
# Processing No.1774, 6854800...
# Processing No.1775, 6854820...
# Processing No.1776, 6854900...
# Processing No.1777, 6854950...
# Processing No.1778, 6855401...
# Processing No.1779, 6855402...
# Processing No.1780, 6870640...
# Processing No.1781, 6934120...
# Processing No.1782, 6934270...
# Processing No.1783, 6934350...
# Processing No.1784, 6934700...
# Processing No.1785, 6935054...
# Processing No.1786, 6935301...
# Processing No.1787, 6955430...
# Processing No.1788, 6970100...
# Processing No.1789, 6970101...
# Processing No.1790, 6970103...
# Processing No.1791, 6970110...
# Processing No.1792, 6970138...
# Processing No.1793, 6970160...
# Processing No.1794, 6970250...
# Processing No.1795, 6970270...
# Processing No.1796, 6970272...
# Processing No.1797, 6970400...
# Processing No.1798, 6970401...
# Processing No.1799, 6970410...
# Processing No.1800, 6970420...
# Processing No.1801, 6970430...
# Processing No.1802, 6970435...
# Processing No.1803, 6970445...
# Processing No.1804, 6970450...
# Processing No.1805, 6970451...
# Processing No.1806, 6970452...
# Processing No.1807, 6970453...
# Processing No.1808, 6970455...
# Processing No.1809, 6970460...
# Processing No.1810, 6970462...
# Processing No.1811, 6970470...
# Processing No.1812, 6970481...
# Processing No.1813, 6970485...
# Processing No.1814, 6970490...
# Processing No.1815, 6970500...
# Processing No.1816, 6970501...
# Processing No.1817, 6970520...
# Processing No.1818, 6970550...
# Processing No.1819, 6970560...
# Processing No.1820, 6970565...
# Processing No.1821, 6970601...
# Processing No.1822, 6970630...
# Processing No.1823, 6970682...
# Processing No.1824, 6970684...
# Processing No.1825, 6970700...
# Processing No.1826, 6970703...
# Processing No.1827, 6970704...
# Processing No.1828, 6970706...
# Processing No.1829, 6970721...
# Processing No.1830, 6970740...
# Processing No.1831, 6970750...
# Processing No.1832, 6970770...
# Processing No.1833, 6970777...
# Processing No.1834, 6970790...
# Processing No.1835, 6970800...
# Processing No.1836, 6970807...
# Processing No.1837, 6970810...
# Processing No.1838, 6970817...
# Processing No.1839, 6970819...
# Processing No.1840, 6970820...
# Processing No.1841, 6970830...
# Processing No.1842, 6970840...
# Processing No.1843, 6970841...
# Processing No.1844, 6970856...
# Processing No.1845, 6970871...
# Processing No.1846, 6970878...
# Processing No.1847, 6970880...
# Processing No.1848, 6970885...
# Processing No.1849, 6970901...
# Processing No.1850, 6970930...
# Processing No.1851, 6971115...
# Processing No.1852, 6971130...
# Processing No.1853, 6971140...
# Processing No.1854, 6975080...
# Processing No.1855, 6975110...
# Processing No.1856, 6975140...
# Processing No.1857, 6975200...
# Processing No.1858, 6975500...
# Processing No.1859, 6976200...
# Processing No.1860, 6976400...
# Processing No.1861, 6978250...
# Processing No.1862, 6978251...
# Processing No.1863, 6978500...
# Processing No.1864, 6983350...
# Processing No.1865, BY_0000011...
# Processing No.1866, BY_0000019...
# Processing No.1867, BY_0000021...
# Processing No.1868, BY_0000024...
# Processing No.1869, BY_0000028...
# Processing No.1870, BY_0000032...
# Processing No.1871, BY_0000033...
# Processing No.1872, ES_0000050...
# Processing No.1873, ES_0000063...
# Processing No.1874, ES_0000155...
# Processing No.1875, ES_0000270...
# Processing No.1876, ES_0000690...
# Processing No.1877, ES_0000706...
# Processing No.1878, ES_0000947...
# Processing No.1879, ES_0000948...
# Processing No.1880, ES_0000982...
# Processing No.1881, ES_0001000...
# Processing No.1882, ES_0001014...
# Processing No.1883, FI_0000077...
# Processing No.1884, FR_0000081...
# Processing No.1885, FR_0000090...
# Processing No.1886, FR_0000304...
# Processing No.1887, FR_0000435...
# Processing No.1888, FR_0000782...
# Processing No.1889, FR_0000790...
# Processing No.1890, FR_0000793...
# Processing No.1891, FR_0000809...
# Processing No.1892, FR_0000910...
# Processing No.1893, FR_0000941...
# Processing No.1894, FR_0000956...
# Processing No.1895, FR_0001095...
# Processing No.1896, RU_0000120...
# Processing No.1897, RU_0000184...
# Processing No.1898, RU_0000217...
# Processing No.1899, RU_0000225...
# Processing No.1900, RU_0000227...
# Processing No.1901, RU_0000233...
# Processing No.1902, RU_0000293...
# Processing No.1903, RU_0000294...
# Processing No.1904, RU_0000296...
# Processing No.1905, RU_0000297...
# Processing No.1906, RU_0000299...
# Processing No.1907, RU_0000301...
# Processing No.1908, RU_0000303...
# Processing No.1909, RU_0000337...
# Processing No.1910, RU_0000354...
# Processing No.1911, RU_0000468...
# Processing No.1912, RU_0000469...
# Processing No.1913, 5803179...
# Processing No.1914, 5864501...
# Processing No.1915, 5865300...
# Processing No.1916, 5865600...
# Processing No.1917, 5866110...
# Processing No.1918, 5866300...
# Processing No.1919, 5868100...
# Processing No.1920, 5101050...
# Processing No.1921, 5101161...
# Processing No.1922, 5101390...
# Processing No.1923, 5101450...
# Processing No.1924, 5104245...
# Processing No.1925, 5109110...
# Processing No.1926, 5109200...
# Processing No.1927, 5109203...
# Processing No.1928, 5109204...
# Processing No.1929, 5109240...
# Processing No.1930, 5109251...
# Processing No.1931, 5110020...
# Processing No.1932, 5110400...
# Processing No.1933, 5202044...
# Processing No.1934, 5202049...
# Processing No.1935, 5202070...
# Processing No.1936, 5202075...
# Processing No.1937, 5202083...
# Processing No.1938, 5202103...
# Processing No.1939, 5202135...
# Processing No.1940, 5202151...
# Processing No.1941, 5202160...
# Processing No.1942, 5202180...
# Processing No.1943, 5204011...
# Processing No.1944, 5204101...
# Processing No.1945, 5204102...
# Processing No.1946, 5204103...
# Processing No.1947, 5204105...
# Processing No.1948, 5204109...
# Processing No.1949, 5204110...
# Processing No.1950, 5204112...
# Processing No.1951, 5204121...
# Processing No.1952, 5204122...
# Processing No.1953, 5204169...
# Processing No.1954, 5204170...
# Processing No.1955, 5204301...
# Processing No.1956, 5204303...
# Processing No.1957, 5302107...
# Processing No.1958, 5302110...
# Processing No.1959, 5302229...
# Processing No.1960, 5302242...
# Processing No.1961, 5302250...
# Processing No.1962, 5302255...
# Processing No.1963, 5302301...
# Processing No.1964, 5302325...
# Processing No.1965, 5302330...
# Processing No.1966, 5302365...
# Processing No.1967, 5304080...
# Processing No.1968, 5304120...
# Processing No.1969, 5402102...
# Processing No.1970, 5402103...
# Processing No.1971, 5405080...
# Processing No.1972, 5410100...
# Processing No.1973, 5606042...
# Processing No.1974, 5606050...
# Processing No.1975, 5606065...
# Processing No.1976, 5606130...
# Processing No.1977, 5606136...
# Processing No.1978, 5606161...
# Processing No.1979, 5606162...
# Processing No.1980, 5606166...
# Processing No.1981, 5606175...
# Processing No.1982, 5607024...
# Processing No.1983, 5607201...
# Processing No.1984, 5607210...
# Processing No.1985, 5607405...
# Processing No.1986, 5607410...
# Processing No.1987, 5607450...
# Processing No.1988, 5607500...
# Processing No.1989, 5607520...
# Processing No.1990, 5607700...
# Processing No.1991, 5608400...
# Processing No.1992, 5708110...
# Processing No.1993, 5708125...
# Processing No.1994, 5708145...
# Processing No.1995, 5708185...
# Processing No.1996, 5709100...
# Processing No.1997, AU_0000014...
# Processing No.1998, AU_0001044...
# Processing No.1999, AU_0001056...
# Processing No.2000, AU_0001063...
# Processing No.2001, AU_0001087...
# Processing No.2002, AU_0001127...
# Processing No.2003, AU_0001128...

# %%
Basin_Properties
# Out:
#             Climate   Clay   Silt   Sand  Longitude  Latitude  Length  Width  \
# stat_num
# ZM_0000050      1.0  33.32  23.68  30.92      32.08     -9.56    1.18   1.98
# ZM_0000053      4.0  33.31  19.11  30.43      30.86     -9.94    0.90   1.16
# ZM_0000043      4.0  32.28  23.44  32.36      30.63    -11.20    4.43   4.32
# CD_0000003      1.0  32.49  20.78  36.20      28.87     -7.87   12.06  10.13
# CD_0000002      1.0  33.80  20.23  37.05      28.59     -6.97   13.54  10.13
# ...             ...    ...    ...    ...        ...       ...     ...    ...
# AU_0001056      5.0  33.92  29.22  36.86     147.69    -36.22    0.41   0.40
# AU_0001063      4.0  27.72  25.49  32.15     147.04    -36.52    0.84   0.61
# AU_0001087      4.0  28.75  28.56  37.41     146.81    -36.81    0.70   0.67
# AU_0001127      4.0  26.07  26.56  35.52     146.14    -37.27    0.82   1.00
# AU_0001128      4.0  28.85  28.46  37.20     145.66    -37.03    1.34   2.00
#
#             Asp_Rat  Slope       Area   BFI     TI         PRE        TMP  \
# stat_num
# ZM_0000050     0.60   0.89   13722.66  0.70  11.06   89.178046  20.699529
# ZM_0000053     0.77   0.82    6418.00  0.71  10.29  104.946810  20.694904
# ZM_0000043     1.03   0.61  123072.00  0.69  11.02   96.684413  20.929631
# CD_0000003     1.19   1.21  810440.00  0.72  10.74   93.779010  22.321537
# CD_0000002     1.34   1.31  948500.00  0.72  10.68   97.301544  22.342193
# ...             ...    ...        ...   ...    ...         ...        ...
# AU_0001056     1.04   4.37     794.02  0.57   8.12   80.030553  12.675478
# AU_0001063     1.38   5.78    1709.31  0.54   8.97   88.600232  12.563449
# AU_0001087     1.05   5.47    2978.38  0.62   9.02  101.191414  12.084911
# AU_0001127     0.81   4.39    3919.81  0.59   8.07  103.598238  12.217561
# AU_0001128     0.67   2.57   16104.12  0.43   9.67   78.444003  13.267958
#
#                    PET       TMAX       TMIN         AE      NDVI
# stat_num
# ZM_0000050  109.215239  26.883955  14.660806  65.095465  0.561711
# ZM_0000053  108.238962  27.107090  14.427384  71.779663  0.616881
# ZM_0000043  108.055383  27.227104  14.674167  69.588950  0.588864
# CD_0000003  107.987029  28.396209  16.313798  75.773421  0.551594
# CD_0000002  106.165601  28.373367  16.519235  81.799050  0.590818
# ...                ...        ...        ...        ...       ...
# AU_0001056   86.780225  18.785833   6.322712  61.816262  0.695044
# AU_0001063   84.347077  19.037145   6.596161  60.339266  0.653257
# AU_0001087   84.495178  17.942234   5.974187  67.914281  0.703940
# AU_0001127   91.358668  17.391523   6.680997  64.081746  0.694438
# AU_0001128   97.111025  19.270307   7.711243  51.928628  0.615883
#
# [2003 rows x 20 columns]
